# %% [markdown]
# # Sequential Hybrid Anemia Screening System
# **Non-Invasive Pediatric Severity Diagnosis via Conjunctiva Imaging**
#
# > *"A digital triage system: the CNN acts as a Virtual Lab Technician extracting biomarkers from the image; the Random Forest acts as the Doctor making the final clinical call."*
#
# ---
#
# ### Pipeline at a Glance
#
# ```
# Raw Photo  →  [Stage 1: Vision Backbone]  →  Hb Estimate + Anemia Probability
#                                                          ↓
#                               + Age (months) + Gender + Collection Site
#                                                          ↓
#                           [Stage 2: Feature Fusion]  →  Patient Profile Vector
#                                                          ↓
#                           [Stage 3: Tabular Classifier]  →  WHO Severity Class
# ```
#
# | Stage | Component | Role |
# |-------|-----------|------|
# | **1** | MobileNetV3-Small (CNN) | Virtual Lab Technician — extracts Hb & anemia probability |
# | **2** | Feature Fusion | Merges visual biomarkers with patient metadata |
# | **3** | Random Forest | Doctor — maps the patient profile to a severity class |
#
# | I/O | Details |
# |-----|---------|
# | **Input** | Conjunctiva image (224×224) · Age (months) · Gender · Collection Site |
# | **Output** | Severity: Normal / Mild / Moderate / Severe · Hb estimate (g/dL) |
# | **Dataset** | CP-AnemiC — pediatric palpebral conjunctiva images (ages 6–60 months) |
# | **Labels** | WHO-grounded 4-class severity thresholds (age-dependent) |
#
# ---

# %% [markdown]
# ---
# ## 1 · Environment Setup
#
# Import all dependencies and configure global constants, random seeds, and file paths.

# %%
import os, warnings, random, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from PIL import Image
import joblib
import shap

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, f1_score, confusion_matrix, classification_report,
    precision_score, recall_score,
    mean_absolute_error, mean_squared_error, r2_score,
)
from sklearn.utils import resample
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras import layers, models, Input
from tensorflow.keras.applications import MobileNetV3Large, MobileNetV3Small
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input   # scales to [-1, 1]
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import load_model

try:
    import tensorflow_model_optimization as tfmot
    _HAS_TFMOT = True
    print('tensorflow-model-optimization available — pruning enabled')
except ImportError:
    _HAS_TFMOT = False
    print('tensorflow-model-optimization not installed — run: pip install tensorflow-model-optimization')

warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print(f'TensorFlow  : {tf.__version__}')
print(f'OpenCV      : {cv2.__version__}')
print(f'NumPy       : {np.__version__}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os, warnings, random, json
# ----> 2 import numpy as np
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
BASE_PATH      = r"c:\Users\USER\Capstone\Bari"
DATA_CSV       = os.path.join(BASE_PATH, "data", "Tabular", "anemia.csv")
IMG_ANEMIC     = os.path.join(BASE_PATH, "data", "Images", "Anemic")
IMG_NON_ANEMIC = os.path.join(BASE_PATH, "data", "Images", "Non-anemic")
MODELS_DIR     = os.path.join(BASE_PATH, "Notebook", "models")
RESULTS_DIR    = os.path.join(BASE_PATH, "Notebook", "results")
TFLITE_DIR     = os.path.join(BASE_PATH, "models", "saved_models")

os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(TFLITE_DIR,  exist_ok=True)

VISUAL_PATH = os.path.join(MODELS_DIR, "visual_model_best.keras")
MM_B_PATH   = os.path.join(MODELS_DIR, "multimodal_no_hb.keras")
TAB_WH_PKL  = os.path.join(MODELS_DIR, "tabular_with_hb.pkl")

IMG_SIZE   = 224
BATCH_SIZE = 32
EPOCHS     = 100
LR         = 1e-4
SEED       = 42

# 4-class severity (WHO-grounded labels used throughout)
CLASS_NAMES = ["Normal", "Mild", "Moderate", "Severe"]
CLASS_MAP   = {c: i for i, c in enumerate(CLASS_NAMES)}
CLASS_MAP["Non-Anemic"] = 0   # map legacy CSV label to Normal
NUM_CLASSES = len(CLASS_NAMES)
COLORS      = ["#2ecc71", "#f39c12", "#e74c3c", "#c0392b"]

# 2-class (visual model — binary, from folder names)
NUM_VISUAL         = 2
VISUAL_CLASS_NAMES = ["Non-Anemic", "Anemic"]

# ── WHO average Hb (g/dL) by age band — used as clinical prior ────────────────
# Source: WHO reference values for children 6–60 months.
# Maps (age_lo_inclusive, age_hi_exclusive) → average Hb g/dL
WHO_AVG_HB = {
    (6,  12): 11.0,   # 6–11 months
    (12, 24): 11.4,   # 12–23 months
    (24, 36): 11.8,   # 24–35 months
    (36, 48): 12.0,   # 36–47 months
    (48, 61): 12.2,   # 48–60 months
}

def who_hb_prior(age_months: float) -> float:
    """Return WHO average Hb for a child's age. Falls back to grand mean."""
    for (lo, hi), val in WHO_AVG_HB.items():
        if lo <= age_months < hi:
            return val
    return 11.5   # fallback for ages outside 6–60 months

# Tabular feature sets
_HIST_FEATS   = [f"a_hist_{i}" for i in range(32)]   # 32-bin a* histogram
_COLOUR_FEATS = [
    "a_mean", "a_std", "b_mean", "G_mean", "l_mean", "lap_var",
    "a_p80",            # 80th-pct of tissue a* — top-end redness
    "a_trim",           # trimmed mean p30–p70 of tissue a* — bulk pallor signal
    "a_mean_site_norm", # a_mean centred by per-clinic training mean — removes lighting bias
]
_DEMO_FEATS   = ["Age(Months)", "Gender_F", "age_baseline_hb"]   # WHO prior added

FEAT_NO_HB   = _COLOUR_FEATS + _HIST_FEATS + _DEMO_FEATS
FEAT_WITH_HB = _COLOUR_FEATS + _HIST_FEATS + ["HB_LEVEL"] + _DEMO_FEATS


def anemia_label(hb: float, age: float, gender: str = "") -> str:
    """
    WHO-grounded severity label from Hb (g/dL) and age (months).
    Returns 'Normal' | 'Mild' | 'Moderate' | 'Severe' | 'Unknown'.
    """
    if 6 <= age < 24:
        if   hb >= 10.5:             return "Normal"
        elif 9.5  <= hb < 10.5:      return "Mild"
        elif 7.0  <= hb <  9.5:      return "Moderate"
        else:                         return "Severe"
    elif 24 <= age <= 60:
        if   hb >= 11.0:             return "Normal"
        elif 10.0 <= hb < 11.0:      return "Mild"
        elif 7.0  <= hb < 10.0:      return "Moderate"
        else:                         return "Severe"
    return "Unknown"


print("Configuration loaded.")
print(f"  4-class : {CLASS_NAMES}")
print(f"  Features (no HB)  [{len(FEAT_NO_HB)}]: {FEAT_NO_HB}")
print(f"  Features (with HB)[{len(FEAT_WITH_HB)}]: {FEAT_WITH_HB}")
# Out:
# Configuration loaded.
#   4-class : ['Normal', 'Mild', 'Moderate', 'Severe']
#   Features (no HB)  [44]: ['a_mean', 'a_std', 'b_mean', 'G_mean', 'l_mean', 'lap_var', 'a_p80', 'a_trim', 'a_mean_site_norm', 'a_hist_0', 'a_hist_1', 'a_hist_2', 'a_hist_3', 'a_hist_4', 'a_hist_5', 'a_hist_6', 'a_hist_7', 'a_hist_8', 'a_hist_9', 'a_hist_10', 'a_hist_11', 'a_hist_12', 'a_hist_13', 'a_hist_14', 'a_hist_15', 'a_hist_16', 'a_hist_17', 'a_hist_18', 'a_hist_19', 'a_hist_20', 'a_hist_21', 'a_hist_22', 'a_hist_23', 'a_hist_24', 'a_hist_25', 'a_hist_26', 'a_hist_27', 'a_hist_28', 'a_hist_29', 'a_hist_30', 'a_hist_31', 'Age(Months)', 'Gender_F', 'age_baseline_hb']
# ...

# %% [markdown]
# ---
# ## 2 · Data Pipeline
#
# ### 2.1 · Data Loading & Exploration
#
# Load `anemia.csv` and inspect raw tabular data — column types, class distribution, and missing values.

# %%
df = pd.read_csv(DATA_CSV)
print("Shape:", df.shape)
print("\nColumn dtypes:")
print(df.dtypes.to_string())
print("\n Summary Statistics ")
display(df.describe())
# Out:
# Shape: (710, 11)
#
# Column dtypes:
# IMAGE_ID                     str
# HB_LEVEL                 float64
# Severity                     str
# Age(Months)                int64
# GENDER                       str
# REMARK                       str
# HOSPITAL                     str
# CITY/TOWN                    str
# MUNICIPALITY/DISTRICT        str
# REGION                       str
# COUNTRY                      str
#
#  Summary Statistics
#          HB_LEVEL  Age(Months)
# count  710.000000   710.000000
# mean    10.358521    31.587324
# std      2.258663    16.783786
# min      3.100000     6.000000
# 25%      8.900000    12.000000
# 50%     10.300000    24.000000
# 75%     12.100000    48.000000
# max     15.000000    60.000000

# %%
print("── Class Distribution ──")
print(df["Severity"].value_counts().to_string())
print()
print("── Missing Values ──")
print(df.isnull().sum().to_string())
print("\nTotal missing:", df.isnull().sum().sum())
df.head()
# Out:
# ── Class Distribution ──
# Severity
# Non-Anemic    286
# Moderate      232
# Mild          144
# Severe         48
#
# ── Missing Values ──
# IMAGE_ID                 0
# HB_LEVEL                 0
# Severity                 0
# Age(Months)              0
# GENDER                   0
# REMARK                   0
# HOSPITAL                 0
# CITY/TOWN                0
# MUNICIPALITY/DISTRICT    0
# REGION                   0
# COUNTRY                  0
#
# Total missing: 0
#     IMAGE_ID  HB_LEVEL    Severity  Age(Months)  GENDER      REMARK  \
# 0  Image_001       9.8    Moderate            6  Female      Anemic
# 1  Image_002       9.9    Moderate           24    Male      Anemic
# 2  Image_003      11.1  Non-Anemic           24  Female  Non-anemic
# 3  Image_004      12.5  Non-Anemic           12    Male  Non-anemic
# 4  Image_005       9.9    Moderate           24    Male      Anemic
#
#                            HOSPITAL     CITY/TOWN   MUNICIPALITY/DISTRICT  \
# ...

# %%
# ── Class distribution plot
counts = [df["Severity"].value_counts().get(c, 0) for c in CLASS_NAMES]

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

bars = axes[0].bar(CLASS_NAMES, counts, color=COLORS)
for b, v in zip(bars, counts):
    axes[0].text(b.get_x() + b.get_width()/2, b.get_height() + 1.5,
                 f"{v}\n({v/len(df)*100:.1f}%)", ha="center", va="bottom", fontsize=10)
axes[0].set_title("Class Distribution", fontsize=13, fontweight="bold")
axes[0].set_xlabel("Severity"); axes[0].set_ylabel("Count")

axes[1].pie(counts, labels=CLASS_NAMES, colors=COLORS, autopct="%1.1f%%", startangle=90)
axes[1].set_title("Class Proportion", fontsize=13, fontweight="bold")

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "class_distribution.png"), dpi=150)
plt.show()

# %% [markdown]
# ### 2.2 · Image Loading
#
# Load each conjunctiva image at full resolution and resize to `IMG_SIZE × IMG_SIZE`.
# No ROI cropping is applied — the full image is used as input.
# CLAHE contrast enhancement is applied later during feature extraction and CNN preprocessing.

# %%
def load_image(image_path: str, size: int = IMG_SIZE) -> np.ndarray | None:
    """Load full image and resize to size × size (no cropping)."""
    img = cv2.imread(image_path)
    if img is None:
        return None
    return cv2.resize(img, (size, size), interpolation=cv2.INTER_AREA)


def _resolve_image_path(folder: str, image_id: str) -> str | None:
    """Try bare name, then .png, then .jpg — return first that exists."""
    for candidate in [image_id, image_id + ".png", image_id + ".jpg"]:
        p = os.path.join(folder, candidate)
        if os.path.exists(p):
            return p
    return None


def batch_load_images(df: pd.DataFrame,
                      anemic_dir: str,
                      non_anemic_dir: str,
                      size: int = IMG_SIZE) -> dict:
    imgs, failed = {}, []
    for _, row in df.iterrows():
        folder = anemic_dir if row["REMARK"] == "Anemic" else non_anemic_dir
        path   = _resolve_image_path(folder, row["IMAGE_ID"])
        if path is None:
            failed.append(row["IMAGE_ID"])
            continue
        img = load_image(path, size=size)
        if img is not None:
            imgs[row["IMAGE_ID"]] = img
        else:
            failed.append(row["IMAGE_ID"])
    print(f"Images loaded : {len(imgs)} / {len(df)}")
    if failed:
        print(f"  Failed ({len(failed)}): {failed[:5]}{'…' if len(failed) > 5 else ''}")
    return imgs


def get_image_path(row) -> str:
    """Return the resolved file path for a non-augmented row."""
    folder = IMG_ANEMIC if row["REMARK"] == "Anemic" else IMG_NON_ANEMIC
    return _resolve_image_path(folder, row["IMAGE_ID"]) or os.path.join(folder, row["IMAGE_ID"])


print("Loading full images (no cropping) …")
roi_dict = batch_load_images(df, IMG_ANEMIC, IMG_NON_ANEMIC)

# Quick visual check
sample_ids  = [k for k in roi_dict
               if len(df.loc[df["IMAGE_ID"] == k, "REMARK"]) > 0
               and df.loc[df["IMAGE_ID"] == k, "REMARK"].values[0] == "Anemic"][:2]
sample_ids += [k for k in roi_dict
               if len(df.loc[df["IMAGE_ID"] == k, "REMARK"]) > 0
               and df.loc[df["IMAGE_ID"] == k, "REMARK"].values[0] != "Anemic"][:2]

if sample_ids:
    fig, axes = plt.subplots(1, len(sample_ids), figsize=(12, 3))
    if len(sample_ids) == 1:
        axes = [axes]
    for ax, sid in zip(axes, sample_ids):
        img_rgb = cv2.cvtColor(roi_dict[sid], cv2.COLOR_BGR2RGB)
        ax.imshow(img_rgb); ax.set_title(sid, fontsize=8); ax.axis("off")
    plt.suptitle("Full Image Samples (no cropping)", fontweight="bold", y=1.02)
    plt.tight_layout()
    plt.savefig(os.path.join(RESULTS_DIR, "image_samples.png"), bbox_inches="tight", dpi=120)
    plt.show()
else:
    print("No images in roi_dict — check that IMG_ANEMIC / IMG_NON_ANEMIC paths are correct.")
# Out:
# Loading full images (no cropping) …
# Images loaded : 710 / 710

# %% [markdown]
# ### 2.3 · Offline Augmentation
#
# Generate 4 augmented copies per original image (horizontal flip, ±15° rotation, brightness/contrast jitter) → 5× dataset size. Augmented copies carry the `_aug{k}` suffix so the group-aware split can keep them together with their source patient.

# %%
# ── Offline Augmentation — matching CP-AnemiC paper (5× per class) ────────────
# Paper: 304 → 1520 Anemic  |  223 → 1115 Non-Anemic  (4 augmented + 1 original)
import random

AUG_BASE           = os.path.join(BASE_PATH, "data", "Images", "Augmented")
AUG_DIR_ANEMIC     = os.path.join(AUG_BASE, "Anemic")
AUG_DIR_NON_ANEMIC = os.path.join(AUG_BASE, "Non-anemic")
os.makedirs(AUG_DIR_ANEMIC,     exist_ok=True)
os.makedirs(AUG_DIR_NON_ANEMIC, exist_ok=True)

def random_augment(img: np.ndarray) -> np.ndarray:
    """Apply random flip, rotation, and brightness/contrast adjustment."""
    # Horizontal flip (50% chance)
    if random.random() > 0.5:
        img = cv2.flip(img, 1)
    # Random rotation ±15°
    angle = random.uniform(-15, 15)
    h, w  = img.shape[:2]
    M     = cv2.getRotationMatrix2D((w // 2, h // 2), angle, 1.0)
    img   = cv2.warpAffine(img, M, (w, h), borderMode=cv2.BORDER_REFLECT)
    # Brightness / contrast jitter
    alpha = random.uniform(0.8, 1.3)   # contrast
    beta  = random.randint(-20, 20)    # brightness
    img   = cv2.convertScaleAbs(img, alpha=alpha, beta=beta)
    return img

N_AUG = 4   # 4 augmented copies + 1 original = 5× total

aug_rows = []
skipped  = 0

for _, row in df.iterrows():
    src = get_image_path(row)
    img = cv2.imread(src)
    if img is None:
        skipped += 1
        continue
    save_dir = AUG_DIR_ANEMIC if row["REMARK"] == "Anemic" else AUG_DIR_NON_ANEMIC

    for k in range(N_AUG):
        aug_img  = random_augment(img.copy())
        aug_id   = f"{row['IMAGE_ID']}_aug{k + 1}"
        aug_path = os.path.join(save_dir, aug_id + ".png")
        cv2.imwrite(aug_path, aug_img)
        new_row              = row.copy()
        new_row["IMAGE_ID"]  = aug_id
        new_row["_aug_path"] = aug_path
        aug_rows.append(new_row)

df_aug = pd.concat([df, pd.DataFrame(aug_rows)], ignore_index=True)

# Add explicit image_path column so downstream cells can use it
def get_any_image_path(row):
    if "_aug_path" in row and pd.notna(row.get("_aug_path")):
        return row["_aug_path"]
    return get_image_path(row)

df_aug["image_path"] = df_aug.apply(get_any_image_path, axis=1)
df["image_path"]     = df.apply(get_image_path, axis=1)

print(f"Original dataset   : {len(df)}")
print(f"After augmentation : {len(df_aug)}")
print(f"  Anemic     : {(df_aug['REMARK'] == 'Anemic').sum()}")
print(f"  Non-Anemic : {(df_aug['REMARK'] != 'Anemic').sum()}")
if skipped:
    print(f"  Skipped (unreadable): {skipped}")

# ── Update roi_dict to include augmented images ───────────────────────────────
print("\nLoading augmented images into roi_dict …")
for _, row in pd.DataFrame(aug_rows).iterrows():
    aug_img = cv2.imread(row["_aug_path"])
    if aug_img is not None:
        roi_dict[row["IMAGE_ID"]] = cv2.resize(aug_img, (IMG_SIZE, IMG_SIZE),
                                                interpolation=cv2.INTER_AREA)

print(f"roi_dict size: {len(roi_dict)} (original + augmented)")
# Out:
# Original dataset   : 710
# After augmentation : 3550
#   Anemic     : 2120
#   Non-Anemic : 1430
#
# Loading augmented images into roi_dict …
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# MemoryError: Unable to allocate 147. KiB for an array with shape (224, 224, 3) and data type uint8
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[7], line 73
#      71     aug_img = cv2.imread(row["_aug_path"])
#      72     if aug_img is not None:
# ---> 73         roi_dict[row["IMAGE_ID"]] = cv2.resize(aug_img, (IMG_SIZE, IMG_SIZE),
#      74                                                 interpolation=cv2.INTER_AREA)
#      76 print(f"roi_dict size: {len(roi_dict)} (original + augmented)")
#
# ...

# %% [markdown]
# ---
# ### 2.4 · LAB Feature Engineering
#
# Convert each image to the **CIE L\*a\*b\*** colour space and extract six colour statistics plus an 8-bin a\* histogram. CLAHE is applied to the L\* channel before extraction to normalise brightness.
#
# | Feature | Description |
# |---------|-------------|
# | `a_mean`, `a_std` | Mean and SD of a\* — primary pallor indicator (lower → more pale) |
# | `b_mean` | Mean of b\* (yellow–blue axis) |
# | `l_mean` | Mean of L\* after CLAHE (brightness) |
# | `G_mean` | Mean of RGB green channel |
# | `lap_var` | Laplacian variance on L\* (texture / edge density) |
# | `a_hist_0..7` | 8-bin normalised histogram of the a\* distribution |

# %%
def extract_lab_features(roi_bgr: np.ndarray) -> dict:
 
    # ── CLAHE on L channel ────────────────────────────────────────────────────
    lab     = cv2.cvtColor(roi_bgr, cv2.COLOR_BGR2LAB)
    L, A, B = cv2.split(lab)
    clahe   = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    L_eq    = clahe.apply(L)
    lab_eq  = cv2.merge([L_eq, A, B])
    _, A_eq, B_eq = cv2.split(lab_eq)

    # ── Green channel from RGB ────────────────────────────────────────────────
    rgb = cv2.cvtColor(roi_bgr, cv2.COLOR_BGR2RGB)
    G   = rgb[:, :, 1]

    # ── Tissue mask (same brightness gate as the CLAHE preprocessor) ─────────
    tissue_mask = (L_eq.astype(np.int16) > 40) & (L_eq.astype(np.int16) < 225)
    tissue_a    = A_eq[tissue_mask].astype(np.float32)
    has_tissue  = len(tissue_a) >= 50

    # ── 32-bin normalised histogram of a* (redness distribution) ─────────────
    hist, _ = np.histogram(A_eq.flatten(), bins=32, range=(0, 256))
    hist_n  = hist.astype("float32") / (hist.sum() + 1e-8)

    # ── Laplacian variance (texture / edge density on L*) ────────────────────
    lap_var = float(cv2.Laplacian(L_eq, cv2.CV_64F).var())

    feats = {
        "a_mean" : float(A_eq.mean()),
        "a_std"  : float(A_eq.std()),
        "b_mean" : float(B_eq.mean()),
        "l_mean" : float(L_eq.mean()),
        "G_mean" : float(G.mean()),
        "lap_var": lap_var,
    }

    # ── Percentile / trimmed-mean features on tissue pixels only ─────────────
    # a_p80:  80th-percentile — upper end of redness distribution
    # a_trim: trimmed mean (p30–p70) — bulk-tissue redness, less sclera noise
    if has_tissue:
        feats["a_p80"]  = float(np.percentile(tissue_a, 80))
        lo, hi          = np.percentile(tissue_a, [30, 70])
        trim            = tissue_a[(tissue_a >= lo) & (tissue_a <= hi)]
        feats["a_trim"] = float(np.mean(trim)) if len(trim) > 0 else float(np.mean(tissue_a))
    else:
        feats["a_p80"]  = float(np.percentile(A_eq, 80))
        feats["a_trim"] = float(A_eq.mean())

    for i, v in enumerate(hist_n):
        feats[f"a_hist_{i}"] = float(v)

    return feats

# %%
# ── Build LAB feature dataframe from roi_dict (original + augmented) ──────────
# Uses df_aug so augmented samples inherit Severity labels for tabular model.
# Visual model uses binary labels (Anemic/Non-Anemic) from REMARK column.

print("Computing LAB + Green channel features …")

records = []
for _, row in df_aug.iterrows():
    roi = roi_dict.get(row["IMAGE_ID"])
    if roi is None:
        continue
    feats = extract_lab_features(roi)
    records.append({**row.to_dict(), **feats})

df_lab = pd.DataFrame(records).reset_index(drop=True)

dropped = len(df_aug) - len(df_lab)
if dropped:
    print(f"  Warning: {dropped} rows dropped (no image found).")

print(f"Features computed  : {len(df_lab)} samples")
print(f"  Original         : {len(df)}")
print(f"  Augmented        : {len(df_lab) - len(df)}")
print(f"\n  a_mean : mean={df_lab['a_mean'].mean():.2f}  std={df_lab['a_mean'].std():.2f}")
print(f"  b_mean : mean={df_lab['b_mean'].mean():.2f}  std={df_lab['b_mean'].std():.2f}")
print(f"  G_mean : mean={df_lab['G_mean'].mean():.2f}  std={df_lab['G_mean'].std():.2f}")
print(f"  l_mean : mean={df_lab['l_mean'].mean():.2f}  std={df_lab['l_mean'].std():.2f}")

# ── Severity distribution (for tabular 4-class model) ─────────────────────────
print(f"\nSeverity distribution (tabular — 4-class):")
print(df_lab["Severity"].value_counts().to_string())

# ── Binary distribution (for visual model) ────────────────────────────────────
print(f"\nBinary distribution (visual — 2-class):")
print(df_lab["REMARK"].value_counts().to_string())
# Out:
# Computing LAB + Green channel features …

# %%
# Overwrite Severity using WHO thresholds (anemia_label) so labels are
# consistent with actual Hb values rather than potentially noisy CSV annotations.
before = df_lab["Severity"].value_counts().to_dict()

df_lab["Severity"] = df_lab.apply(
    lambda r: anemia_label(r["HB_LEVEL"], r["Age(Months)"], r.get("GENDER", "")),
    axis=1,
)

# Drop rows where age is outside 6-60 months (anemia_label returns "Unknown")
unknown_mask = df_lab["Severity"] == "Unknown"
if unknown_mask.sum() > 0:
    print(f"Dropping {unknown_mask.sum()} rows with age outside 6-60 months.")
    df_lab = df_lab[~unknown_mask].reset_index(drop=True)

after = df_lab["Severity"].value_counts().to_dict()

print("Severity label distribution — before vs after WHO overwrite:")
print(f"  {'Label':12s}  {'Before':>8}  {'After':>8}")
for label in CLASS_NAMES:
    print(f"  {label:12s}  {before.get(label, before.get('Non-Anemic' if label=='Normal' else label, 0)):>8}  {after.get(label, 0):>8}")
print(f"\n  Total: {sum(before.values())} → {len(df_lab)}")
# Out:
# Severity label distribution — before vs after WHO overwrite:
#   Label           Before     After
#   Normal            1430      1495
#   Mild               720       755
#   Moderate          1160      1060
#   Severe             240       240
#
#   Total: 3550 → 3550

# %% [markdown]
# ---
# ### 2.5 · Exploratory Data Analysis & Outlier Detection
#
# Apply **IQR-based outlier removal** on `a_mean` (1.5× multiplier). Visualise feature distributions and Hb level spread by severity class after cleaning.

# %%
def remove_outliers_iqr(df: pd.DataFrame,
                        column: str,
                        multiplier: float = 1.5) -> pd.DataFrame:
    q1, q3 = df[column].quantile([0.25, 0.75])
    iqr     = q3 - q1
    lo, hi  = q1 - multiplier * iqr, q3 + multiplier * iqr
    mask    = df[column].between(lo, hi)
    n_out   = (~mask).sum()
    print(f"IQR outlier removal on '{column}':")
    print(f"  Q1={q1:.2f}  Q3={q3:.2f}  IQR={iqr:.2f}")
    print(f"  Fence: [{lo:.2f}, {hi:.2f}]")
    print(f"  Removed {n_out} outliers ({n_out / len(df) * 100:.1f} %)")
    return df[mask].reset_index(drop=True)


df_clean = remove_outliers_iqr(df_lab, column="a_mean")
print(f"\nDataset after cleaning: {df_clean.shape}")
print("\nClass distribution after cleaning:")
print(df_clean["Severity"].value_counts().to_string())
# Out:
# IQR outlier removal on 'a_mean':
#   Q1=133.15  Q3=137.04  IQR=3.88
#   Fence: [127.33, 142.86]
#   Removed 26 outliers (0.7 %)
#
# Dataset after cleaning: (3524, 53)
#
# Class distribution after cleaning:
# Severity
# Normal      1484
# Moderate    1053
# Mild         752
# Severe       235

# %%
# ── EDA: a_mean and HB_LEVEL distributions after cleaning ────────────────────
df_clean["Age_Years"] = df_clean["Age(Months)"] / 12

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Boxplot: a_mean by severity
data_a = [df_clean[df_clean["Severity"] == s]["a_mean"].values for s in CLASS_NAMES]
bp = axes[0].boxplot(data_a, labels=CLASS_NAMES, patch_artist=True)
for patch, col in zip(bp["boxes"], COLORS):
    patch.set_facecolor(col)
axes[0].axhline(128, ls="--", color="gray", lw=1, label="neutral a*=128")
axes[0].set_title("a_mean by Severity (cleaned)", fontweight="bold")
axes[0].set_ylabel("a_mean")
axes[0].legend(fontsize=8)

# Boxplot: HB_LEVEL by severity
data_hb = [df_clean[df_clean["Severity"] == s]["HB_LEVEL"].values for s in CLASS_NAMES]
bp2 = axes[1].boxplot(data_hb, labels=CLASS_NAMES, patch_artist=True)
for patch, col in zip(bp2["boxes"], COLORS):
    patch.set_facecolor(col)
axes[1].set_title("HB_LEVEL by Severity (reference only)", fontweight="bold")
axes[1].set_ylabel("Hemoglobin (g/dL)")

# Age distribution by severity
for s, col in zip(CLASS_NAMES, COLORS):
    axes[2].hist(df_clean[df_clean["Severity"] == s]["Age_Years"],
                 bins=15, alpha=0.55, color=col, label=s)
axes[2].set_title("Age Distribution by Severity", fontweight="bold")
axes[2].set_xlabel("Age (years)")
axes[2].legend()

plt.suptitle("EDA: Feature Distributions After Outlier Removal", fontweight="bold")
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "eda_distributions.png"), bbox_inches="tight", dpi=120)
plt.show()

print(f"Final clean dataset: {df_clean.shape[0]} samples, {df_clean.shape[1]} columns")
# Out:
# Final clean dataset: 3524 samples, 54 columns

# %% [markdown]
# ---
# ### 2.6 · Dataset Preparation
#
# Apply a **group-aware stratified split** (70 / 10 / 20) keyed on `base_id` so augmented copies of the same patient always stay in the same fold. Fit `StandardScaler` on the training set only.
#
# | Split | Size | Feature matrices | Labels |
# |-------|------|-----------------|--------|
# | Train | 70% | `Xnh_tr`, `Xwh_tr` | `y_tr`, `hb_tr`, `lbl_tr` |
# | Val   | 10% | `Xnh_vl`, `Xwh_vl` | `y_vl`, `hb_vl`, `lbl_vl` |
# | Test  | 20% | `Xnh_te`, `Xwh_te` | `y_te`, `hb_te`, `lbl_te` |

# %%
import re
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

df_clean["Gender_F"] = (df_clean["GENDER"].str.lower() == "female").astype(int)
df_clean["label"]    = df_clean["Severity"].map(CLASS_MAP)
df_clean = df_clean.dropna(subset=["label"]).reset_index(drop=True)
df_clean["label"] = df_clean["label"].astype(int)

# ── Stage 2 feature: Collection Site ─────────────────────────────────────────
_site_enc = LabelEncoder()
df_clean["Site_ID"] = _site_enc.fit_transform(
    df_clean["CITY/TOWN"].fillna("Unknown").str.strip()
)
NUM_SITES = int(df_clean["Site_ID"].nunique())
print(f"Screening sites ({len(_site_enc.classes_)}): {list(_site_enc.classes_)}")

# ── WHO age-prior: clinical baseline Hb for each child's age ─────────────────
df_clean["age_baseline_hb"] = df_clean["Age(Months)"].apply(who_hb_prior)

# ── Age-band: discretise age into 4 bands matching a*–Hb signal strength ─────
# Band 0 (6–12 mo):  r = -0.452  strong visual signal — image is informative
# Band 1 (12–24 mo): r =  0.032  near-zero signal    — rely on age prior
# Band 2 (24–36 mo): r = -0.027  near-zero signal    — rely on age prior
# Band 3 (36–60 mo): r = -0.119  weak signal         — partial image use
# The embedding lets the model learn to gate how much it trusts the image
# vs. the clinical prior for each age group.
def age_band(age):
    if age < 12: return 0
    if age < 24: return 1
    if age < 36: return 2
    return 3

NUM_BANDS = 4
df_clean["age_band"] = df_clean["Age(Months)"].apply(age_band)
print(f"Age-band distribution:\n{df_clean['age_band'].value_counts().sort_index()}")

df_clean["image_path"] = df_clean.apply(get_any_image_path, axis=1)
df_clean["base_id"] = df_clean["IMAGE_ID"].apply(lambda x: re.sub(r"_aug\d+$", "", str(x)))

# ── Group-aware stratified split (70 / 15 / 15) ───────────────────────────────
base_df  = df_clean.groupby("base_id")["label"].first().reset_index()
base_ids = base_df["base_id"].to_numpy()
base_lbl = base_df["label"].to_numpy(dtype=int)

base_tr_tmp, base_te = train_test_split(base_ids, test_size=0.15, stratify=base_lbl, random_state=SEED)
base_tr, base_vl     = train_test_split(
    base_tr_tmp, test_size=round(0.15 / 0.85, 4),
    stratify=base_lbl[np.isin(base_ids, base_tr_tmp)],
    random_state=SEED,
)

idx_tr = df_clean.index[df_clean["base_id"].isin(base_tr)].values
idx_vl = df_clean.index[df_clean["base_id"].isin(base_vl)].values
idx_te = df_clean.index[df_clean["base_id"].isin(base_te)].values

# ── Site-normalised a*: removes per-clinic lighting offset ───────────────────
# Mean computed from training indices only — no leakage from val/test Hb labels.
# Each sample's a_mean is centred by its clinic's average redness in training data.
site_amean_tr = df_clean.loc[idx_tr].groupby("Site_ID")["a_mean"].mean()
df_clean["a_mean_site_norm"] = (
    df_clean["a_mean"] - df_clean["Site_ID"].map(site_amean_tr).fillna(0)
)
print(f"Site-norm a* — train mean: {df_clean.loc[idx_tr, 'a_mean_site_norm'].mean():.4f} "
      f"(should be ~0)  std: {df_clean.loc[idx_tr, 'a_mean_site_norm'].std():.3f}")

# ── Feature arrays ─────────────────────────────────────────────────────────────
X_no_hb   = df_clean[FEAT_NO_HB].to_numpy(dtype=float)
X_with_hb = df_clean[FEAT_WITH_HB].to_numpy(dtype=float)
y         = df_clean["label"].to_numpy(dtype=int)
hb_vals   = df_clean["HB_LEVEL"].fillna(df_clean["HB_LEVEL"].mean()).to_numpy(dtype="float32")
img_paths = df_clean["image_path"].to_numpy()
img_labels= (df_clean["REMARK"].str.strip() == "Anemic").to_numpy(dtype="int32")
site_all  = df_clean["Site_ID"].to_numpy(dtype="int32")
band_all  = df_clean["age_band"].to_numpy(dtype="int32")

# ── Clinical-only features for the fusion model ───────────────────────────────
FEAT_CLINICAL = ["Age(Months)", "Gender_F", "age_baseline_hb"]
X_clin = df_clean[FEAT_CLINICAL].to_numpy(dtype=float)

# ── Apply splits ───────────────────────────────────────────────────────────────
X_nh_tr, X_nh_vl, X_nh_te       = X_no_hb[idx_tr],   X_no_hb[idx_vl],   X_no_hb[idx_te]
X_wh_tr, X_wh_vl, X_wh_te       = X_with_hb[idx_tr], X_with_hb[idx_vl], X_with_hb[idx_te]
X_clin_tr, X_clin_vl, X_clin_te = X_clin[idx_tr],    X_clin[idx_vl],    X_clin[idx_te]
y_tr,    y_vl,    y_te           = y[idx_tr],          y[idx_vl],          y[idx_te]
p_tr,    p_vl,    p_te           = img_paths[idx_tr],  img_paths[idx_vl],  img_paths[idx_te]
hb_tr,   hb_vl,  hb_te          = hb_vals[idx_tr],    hb_vals[idx_vl],    hb_vals[idx_te]
lbl_tr,  lbl_vl, lbl_te         = img_labels[idx_tr], img_labels[idx_vl], img_labels[idx_te]
site_tr, site_vl, site_te       = site_all[idx_tr],   site_all[idx_vl],   site_all[idx_te]
band_tr, band_vl, band_te       = band_all[idx_tr],   band_all[idx_vl],   band_all[idx_te]

# ── Scale tabular features ────────────────────────────────────────────────────
scaler_nh = StandardScaler().fit(X_nh_tr)
scaler_wh = StandardScaler().fit(X_wh_tr)
Xnh_tr, Xnh_vl, Xnh_te = (scaler_nh.transform(X_nh_tr),
                            scaler_nh.transform(X_nh_vl),
                            scaler_nh.transform(X_nh_te))
Xwh_tr, Xwh_vl, Xwh_te = (scaler_wh.transform(X_wh_tr),
                            scaler_wh.transform(X_wh_vl),
                            scaler_wh.transform(X_wh_te))

# Fusion model clinical branch: MinMaxScaler → [0, 1]
scaler_clin = MinMaxScaler().fit(X_clin_tr)
Xclin_tr = scaler_clin.transform(X_clin_tr).astype("float32")
Xclin_vl = scaler_clin.transform(X_clin_vl).astype("float32")
Xclin_te = scaler_clin.transform(X_clin_te).astype("float32")

print(f"Split sizes — Train: {len(idx_tr)}  Val: {len(idx_vl)}  Test: {len(idx_te)}")
print(f"Tabular features (no HB): {len(FEAT_NO_HB)}  |  Site embedding: {NUM_SITES} clinics  |  Age bands: {NUM_BANDS}")
# Out:
# Screening sites (8): ['Berekum', 'Bolgatanga', 'Ejusu', 'Kintampo', 'Kumasi', 'Nkawie-Toase', 'Sunyani', 'Tachiman']
# Age-band distribution:
# age_band
# 0     114
# 1     891
# 2     766
# 3    1753
# Name: count, dtype: int64
# Site-norm a* — train mean: 0.0000 (should be ~0)  std: 2.606
# Split sizes — Train: 2459  Val: 531  Test: 534
# Tabular features (no HB): 44  |  Site embedding: 8 clinics  |  Age bands: 4

# %% [markdown]
# ### 2.7 · Image Quality Analysis
#
# Verify blur levels, brightness distribution, and resolution consistency across the dataset. Flags images with unusually low Laplacian variance (likely blurry) for awareness.

# %%
# ── RF helpers — defined here so they are available to all model sections ─────
import warnings
from sklearn.model_selection import GridSearchCV, StratifiedKFold
warnings.filterwarnings('ignore', category=UserWarning, module='sklearn')

# Grid search over the two hyperparameters specified in the Two-Phase Training spec
_rf_param_grid = {
    "n_estimators": [100, 200, 300, 500],
    "max_depth":    [5, 8, 10, 12, 15, None],
}
_rf_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)

def tune_rf(X_tr, y_tr, name):
    """GridSearchCV over n_estimators and max_depth, optimising f1_macro."""
    print(f"Hyperparameter search — {name} ...")
    search = GridSearchCV(
        RandomForestClassifier(random_state=SEED, n_jobs=-1,
                               class_weight="balanced"),
        _rf_param_grid, cv=_rf_cv, scoring="f1_macro",
        n_jobs=-1, verbose=0,
    )
    search.fit(X_tr, y_tr)
    print(f"  Best F1 macro (CV): {search.best_score_:.4f}")
    print(f"  Best params: {search.best_params_}")
    return search.best_estimator_


def eval_rf(model, X_tr, X_vl, X_te, y_tr, y_vl, y_te):
    """Print Train / Val / Test accuracy and macro F1 for an RF model."""
    for split, X, y in [("Train", X_tr, y_tr), ("Val", X_vl, y_vl), ("Test", X_te, y_te)]:
        preds = model.predict(X)
        acc   = accuracy_score(y, preds)
        f1    = f1_score(y, preds, average="macro", zero_division=0)
        print(f"  {split:5s} — Acc: {acc:.4f}  F1 macro: {f1:.4f}")

print("RF helpers ready — tune_rf / eval_rf defined.")
# Out:
# RF helpers ready — tune_rf / eval_rf defined.

# %%
# ── Image Quality Analysis ────────────────────────────────────────────────────
import cv2, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob

all_paths = (
    glob(os.path.join(IMG_ANEMIC,     "*.jpg")) +
    glob(os.path.join(IMG_ANEMIC,     "*.png")) +
    glob(os.path.join(IMG_NON_ANEMIC, "*.jpg")) +
    glob(os.path.join(IMG_NON_ANEMIC, "*.png"))
)
print(f"Total images found: {len(all_paths)}")

records = []
for p in all_paths:
    img = cv2.imread(p)
    if img is None:
        continue
    h, w = img.shape[:2]
    gray  = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Sharpness — Laplacian variance (higher = sharper)
    sharpness = cv2.Laplacian(gray, cv2.CV_64F).var()
    # Brightness — mean pixel value (0-255)
    brightness = gray.mean()
    # Contrast — std of pixel values
    contrast = gray.std()
    records.append({
        "file": os.path.basename(p),
        "width": w, "height": h,
        "sharpness": round(sharpness, 2),
        "brightness": round(brightness, 2),
        "contrast": round(contrast, 2),
    })

df_q = pd.DataFrame(records)

print(f"\n── Resolution ──────────────────────────")
print(df_q[["width","height"]].describe().round(1).to_string())
print(f"\n── Quality Metrics ─────────────────────")
print(df_q[["sharpness","brightness","contrast"]].describe().round(2).to_string())

# Flag low-quality images
blurry   = df_q[df_q["sharpness"]   < 100]
dark     = df_q[df_q["brightness"]  < 50]
bright   = df_q[df_q["brightness"]  > 200]
low_cont = df_q[df_q["contrast"]    < 20]

print(f"\n⚠  Blurry  (sharpness < 100) : {len(blurry)}")
print(f"⚠  Too dark (brightness < 50) : {len(dark)}")
print(f"⚠  Too bright (brightness > 200): {len(bright)}")
print(f"⚠  Low contrast (std < 20)   : {len(low_cont)}")

# Plot distributions
fig, axes = plt.subplots(1, 3, figsize=(14, 4))
for ax, col, color in [
    (axes[0], "sharpness",  "#5B9EC9"),
    (axes[1], "brightness", "#F4A261"),
    (axes[2], "contrast",   "#2A9D8F"),
]:
    ax.hist(df_q[col], bins=30, color=color, edgecolor="white")
    ax.set_title(col.capitalize(), fontweight="bold")
    ax.axvline(df_q[col].mean(), color="red", linestyle="--", label=f"mean={df_q[col].mean():.1f}")
    ax.legend()
plt.suptitle("Image Quality Distribution", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "image_quality.png"), dpi=120)
plt.show()
# Out:
# Total images found: 710
#
# ── Resolution ──────────────────────────
#        width  height
# count  710.0   710.0
# mean   239.1   100.1
# std     73.9    47.4
# min     79.0    33.0
# 25%    184.0    69.0
# 50%    228.0    88.0
# 75%    291.8   112.0
# max    513.0   273.0
#
# ── Quality Metrics ─────────────────────
#        sharpness  brightness  contrast
# count     710.00      710.00    710.00
# mean     2122.86       38.52     62.83
# std      1254.07       14.28     15.87
# min       213.59        6.50     19.75
# 25%      1150.24       28.10     52.92
# 50%      1899.05       36.79     63.77
# 75%      2853.85       47.04     75.41
# max      6899.67       91.69    107.80
#
# ⚠  Blurry  (sharpness < 100) : 0
# ⚠  Too dark (brightness < 50) : 576
# ⚠  Too bright (brightness > 200): 0
# ⚠  Low contrast (std < 20)   : 1

# %% [markdown]
# ---
# ## Stage 1 · Vision Backbone — "Virtual Lab Technician"
# ### MobileNetV3-Small · Dual-Head CNN
#
# The Vision Backbone acts as a **non-invasive lab technician**: it examines the conjunctiva image and returns two clinical biomarkers that feed Stage 2.
#
# | Output | Head | Clinical meaning |
# |--------|------|-----------------|
# | `hb_output` | Linear regression | Predicted Hb level (g/dL) |
# | `cls_output` | 2-class softmax | P(Anemic) — binary detection confidence |
#
# **Why MobileNetV3-Small?** Optimised for mobile hardware; ImageNet transfer learning compensates for small dataset size.
#
# **Input preprocessing:** Images are converted to LAB colour space after CLAHE (clip=1.5). The raw LAB channels are passed to the model so that **channel 1 = a\* (red-green axis)**, which has the highest Hb correlation per NIH literature. The standard `preprocess_input` scale applies equally to LAB [0,255] values.
#
# **Progressive unfreeze schedule:**
#
# | Phase | Backbone | LR | Loss weights | Notes |
# |-------|----------|----|-------------|-------|
# | 1 | Fully frozen | 1e-4 | cls=0.2, hb=0.8 | Train heads only |
# | 2 | Top 25% unfrozen | 1e-5 | cls=0.2, hb=0.8 | Fine-tune upper layers |
# | 3 | Top 50% unfrozen | 5e-6 | cls=0.1, hb=0.9 | Deep regression focus |
#
# Loss: `0.2 × CrossEntropy` + `0.8 × MSE` (Phase 1/2) → `0.1 × CrossEntropy` + `0.9 × MSE` (Phase 3)

# %% [markdown]
# ### 4.1 · Image Pipeline & Dataset Functions
#
# CLAHE preprocessing, online augmentation (brightness, contrast, hue, saturation, coarse dropout), and `tf.data` dataset builders. All images are preloaded into RAM to eliminate slow remote storage I/O during training.

# %%
# ── CLAHE brightness normalisation ────────────────────────────────────────────
def _apply_clahe_np(img_np: np.ndarray) -> np.ndarray:
    """CLAHE on L channel, then mask out sclera and skin — keep conjunctiva only."""
    img_u8  = np.clip(img_np, 0, 255).astype(np.uint8)
    lab     = cv2.cvtColor(img_u8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    clahe   = cv2.createCLAHE(clipLimit=1.5, tileGridSize=(8, 8))
    L_eq    = clahe.apply(L)
    lab_eq  = cv2.merge([L_eq, A, B])

    # ── Conjunctiva mask ──────────────────────────────────────────────────────
    # Mask by BRIGHTNESS only — not by redness.
    # Anemic conjunctiva is pale (low a*) so an a*-based mask would remove
    # the very patients with low Hb, destroying the regression signal.
    # Keep tissue pixels: not pitch-dark (eyelashes/skin) and not pure-white (sclera).
    mask = (
        (L_eq.astype(np.int16) > 40) &    # remove dark eyelashes / skin
        (L_eq.astype(np.int16) < 225)     # remove bright white sclera
    ).astype(np.uint8)

    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    mask   = cv2.morphologyEx(mask, cv2.MORPH_OPEN,  kernel)
    mask   = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    mask3  = mask[:, :, np.newaxis]

    # Fill masked-out pixels with LAB neutral grey
    neutral = np.array([128, 128, 128], dtype=np.float32)
    out     = lab_eq.astype(np.float32) * mask3 + neutral * (1 - mask3)
    return out

# ── PIL-based single-image loader (no tf.io, safe on Google Drive) ────────────
def _load_img_np(path) -> np.ndarray:
    """Load one image via PIL → resize → CLAHE → float32 [0,255]."""
    from PIL import Image as _PIL
    p = path.decode() if isinstance(path, bytes) else str(path)
    img = _PIL.open(p).convert("RGB").resize((IMG_SIZE, IMG_SIZE), _PIL.BILINEAR)
    return _apply_clahe_np(np.array(img, dtype=np.float32))

def _preload_images(paths) -> np.ndarray:
    """Read all images into (N, H, W, 3) float32 RAM array — eliminates Drive I/O."""
    n   = len(paths)
    out = np.empty((n, IMG_SIZE, IMG_SIZE, 3), dtype=np.float32)
    for i, p in enumerate(paths):
        out[i] = _load_img_np(p)
        if (i + 1) % 200 == 0 or (i + 1) == n:
            print(f"\r  Preloading … {i+1}/{n}", end="", flush=True)
    print()
    return out

def _lazy_load_generator(paths, labels, hb_values):
    """Generator: yield (img, label, hb) tuples on-demand — memory-efficient."""
    for p, l, h in zip(paths, labels, hb_values):
        img = _load_img_np(p)
        yield img, l, h

# ── TF-native augmentation (no file I/O — runs on in-memory tensors) ──────────
def colour_augment(img):
    img   = tf.image.random_brightness(img, max_delta=0.2 * 255.0)
    img   = tf.image.random_contrast(img, lower=0.8, upper=1.2)
    img01 = img / 255.0
    img01 = tf.image.random_hue(img01, max_delta=0.05)
    img01 = tf.image.random_saturation(img01, lower=0.7, upper=1.3)
    return tf.clip_by_value(img01 * 255.0, 0.0, 255.0)

def geometric_augment(img):
    img = tf.image.random_flip_left_right(img)
    k   = tf.random.uniform((), 0, 4, dtype=tf.int32)
    return tf.image.rot90(img, k=k)

def coarse_dropout(img, prob=0.5, hole_size=0.15):
    def _apply():
        h  = tf.shape(img)[0]; w = tf.shape(img)[1]
        sh = tf.cast(tf.cast(h, tf.float32) * hole_size, tf.int32)
        sw = tf.cast(tf.cast(w, tf.float32) * hole_size, tf.int32)
        top  = tf.random.uniform((), 0, h - sh, dtype=tf.int32)
        left = tf.random.uniform((), 0, w - sw, dtype=tf.int32)
        mask = tf.image.pad_to_bounding_box(tf.ones([sh, sw, 3], dtype=img.dtype), top, left, h, w)
        fill = tf.reduce_mean(img) * tf.ones_like(img)
        return img * (1.0 - mask) + fill * mask
    return tf.cond(tf.random.uniform(()) < prob, _apply, lambda: img)

def augment_fn(img):
    # Colour augmentation removed: random hue/brightness/saturation changes
    # corrupt the a* signal that correlates with Hb, preventing regression convergence.
    # Only geometry-preserving augmentations are applied.
    # hole_size reduced 0.15→0.06, prob reduced 0.5→0.25: Grad-CAM showed original
    # settings covered 40-55% of conjunctiva tissue, preventing feature learning.
    img = geometric_augment(img)
    img = coarse_dropout(img, prob=0.25, hole_size=0.06)
    return img

# ── Compatibility wrappers (used by Grad-CAM, TTA, inference cells) ─────────
def load_and_preprocess(path) -> tf.Tensor:
    """PIL load → CLAHE → MobileNetV3 normalisation → (H, W, 3) float32 tensor."""
    arr = _load_img_np(path)
    return tf.constant(preprocess_input(arr), dtype=tf.float32)

def load_and_preprocess_augmented(path) -> tf.Tensor:
    """Same as load_and_preprocess with TF augmentation applied."""
    arr = _load_img_np(path)
    img = tf.constant(arr, dtype=tf.float32)
    return preprocess_input(augment_fn(img))

# ── Dataset pipeline — lazy load images to RAM (memory-efficient) ──────────────
def make_image_ds(paths, labels, hb_values, shuffle=True, augment=None, lazy_load=True):
    """
    Create tf.data.Dataset with optional lazy loading.
    lazy_load=True: stream images from disk (memory-efficient for large datasets).
    lazy_load=False: preload all images to RAM (faster but high memory usage).
    """
    if augment is None:
        augment = shuffle

    if not lazy_load:
        # Original preload approach — keep for small datasets
        imgs_np = _preload_images(paths)   # (N, H, W, 3) float32 [0,255], CLAHE applied
        ds = tf.data.Dataset.from_tensor_slices((
            imgs_np,
            labels.astype("int32"),
            hb_values.astype("float32"),
        ))
    else:
        # Lazy load: stream images from disk on-the-fly
        def gen():
            for p, l, h in zip(paths, labels, hb_values):
                img = _load_img_np(p).astype(np.float32)
                yield img, int(l), float(h)
        
        ds = tf.data.Dataset.from_generator(
            gen,
            output_signature=(
                tf.TensorSpec(shape=(IMG_SIZE, IMG_SIZE, 3), dtype=tf.float32),
                tf.TensorSpec(shape=(), dtype=tf.int32),
                tf.TensorSpec(shape=(), dtype=tf.float32),
            )
        )

    if augment:
        ds = ds.map(
            lambda img, l, h: (
                preprocess_input(augment_fn(img)),
                {"cls_output": tf.cast(l, tf.float32),
                 "hb_output":  tf.expand_dims(h, -1)},
            ),
            num_parallel_calls=tf.data.AUTOTUNE,
        )
    else:
        ds = ds.map(
            lambda img, l, h: (
                preprocess_input(img),
                {"cls_output": tf.cast(l, tf.float32),
                 "hb_output":  tf.expand_dims(h, -1)},
            ),
            num_parallel_calls=tf.data.AUTOTUNE,
        )

    if shuffle:
        ds = ds.shuffle(512, seed=SEED, reshuffle_each_iteration=True)
    return ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

def make_balanced_image_ds(paths, labels, hb_values, lazy_load=True):
    """Create balanced dataset with optional lazy loading (default: True for memory efficiency)."""
    df_tmp = pd.DataFrame({"path": paths, "label": labels, "hb": hb_values})
    max_count = df_tmp["label"].value_counts().max()
    df_balanced = pd.concat([
        resample(group, replace=True, n_samples=max_count, random_state=SEED)
        for _, group in df_tmp.groupby("label")
    ], ignore_index=True).sample(frac=1, random_state=SEED).reset_index(drop=True)
    return make_image_ds(
        df_balanced["path"].values,
        df_balanced["label"].values,
        df_balanced["hb"].values,
        shuffle=True,
        lazy_load=lazy_load,
    )

# ── CBAM Attention Block ───────────────────────────────────────────────────────
# Focuses the network on conjunctival tissue rather than sclera/eyelids.
# Channel attention: which feature maps matter; Spatial attention: where to look.
# Custom layers avoid Lambda serialization issues in Keras 3 safe mode.
class _ChanMeanPool(tf.keras.layers.Layer):
    """Average-pool across channel axis for CBAM spatial attention."""
    def call(self, x):
        return tf.reduce_mean(x, axis=-1, keepdims=True)

class _ChanMaxPool(tf.keras.layers.Layer):
    """Max-pool across channel axis for CBAM spatial attention."""
    def call(self, x):
        return tf.reduce_max(x, axis=-1, keepdims=True)

def cbam_block(x, reduction_ratio=16):
    C = x.shape[-1]
    # Channel Attention
    avg_c = layers.GlobalAveragePooling2D()(x)
    max_c = layers.GlobalMaxPooling2D()(x)
    fc1   = layers.Dense(max(C // reduction_ratio, 1), activation="relu",
                         kernel_regularizer=l2(1e-4))
    fc2   = layers.Dense(C, kernel_regularizer=l2(1e-4))
    ca    = layers.Activation("sigmoid")(
                layers.Add()([fc2(fc1(avg_c)), fc2(fc1(max_c))]))
    ca    = layers.Reshape((1, 1, C))(ca)
    x     = layers.Multiply()([x, ca])
    # Spatial Attention — proper custom layers (no Lambda) for safe serialization
    avg_s = _ChanMeanPool()(x)
    max_s = _ChanMaxPool()(x)
    sa    = layers.Concatenate(axis=-1)([avg_s, max_s])
    sa    = layers.Conv2D(1, kernel_size=7, padding="same",
                          activation="sigmoid", kernel_regularizer=l2(1e-4))(sa)
    return layers.Multiply()([x, sa])

# ── MC Dropout — Dropout always active at inference for uncertainty estimation ─
class MCDropout(tf.keras.layers.Dropout):
    def call(self, inputs, training=None):
        return super().call(inputs, training=True)

# ── Model: MobileNetV3Small + CBAM ────────────────────────────────────────────
# Architecture matches paper: shared backbone → sigmoid(1) + linear(1) outputs.
# CBAM inserted between backbone feature maps and GAP to learn conjunctiva focus.
# MCDropout in shared trunk enables uncertainty quantification at inference.
def build_model():
    base_model = MobileNetV3Small(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False,
        weights="imagenet",
    )
    for layer in base_model.layers:
        layer.trainable = False

    x      = base_model.output          # (B, 7, 7, 576)
    x      = cbam_block(x)              # ← channel + spatial attention
    x      = layers.GlobalAveragePooling2D()(x)
    x      = layers.BatchNormalization()(x)
    shared = layers.Dense(256, activation="relu", kernel_regularizer=l2(1e-4))(x)
    shared = MCDropout(0.4)(shared)     # ← MC Dropout (active at inference too)
    shared = layers.Dense(128, activation="relu", kernel_regularizer=l2(1e-4))(shared)
    shared = MCDropout(0.3)(shared)

    # sigmoid(1): binary anemia diagnosis — matches paper specification
    cls_out = layers.Dense(1, activation="sigmoid", name="cls_output")(shared)

    # linear(1): Hb estimation — single layer directly from shared trunk
    hb_out  = layers.Dense(1, activation="linear",  name="hb_output")(shared)

    model = models.Model(
        inputs=base_model.input,
        outputs={"cls_output": cls_out, "hb_output": hb_out},
    )
    return model, base_model

# ── MC Dropout uncertainty prediction ─────────────────────────────────────────
def predict_with_uncertainty(model, img_tensor, n_samples=30):
    """Run n_samples forward passes with Dropout active; return mean + std."""
    cls_stack, hb_stack = [], []
    for _ in range(n_samples):
        out = model(img_tensor, training=True)
        cls_stack.append(float(out["cls_output"][0, 0]))
        hb_stack.append(float(out["hb_output"][0, 0]))
    p_anemic  = float(np.mean(cls_stack))
    hb_mean   = float(np.mean(hb_stack)) * HB_STD + HB_MEAN
    hb_std    = float(np.std(hb_stack))  * HB_STD
    return {
        "p_anemic":       round(p_anemic, 4),
        "hb_estimate":    round(hb_mean, 2),
        "hb_uncertainty": round(hb_std,  2),   # ±1 std in g/dL
        "refer_for_test": hb_std > 1.5,
    }

# ── Binary labels ─────────────────────────────────────────────────────────────
y_tr_bin, y_vl_bin, y_te_bin = lbl_tr, lbl_vl, lbl_te

print(f"Binary train: {np.bincount(y_tr_bin)}  (0=Non-Anemic, 1=Anemic)")
print(f"Binary val  : {np.bincount(y_vl_bin)}")
print(f"Binary test : {np.bincount(y_te_bin)}")

# ── Normalise Hb targets (z-score, computed on train only) ───────────────────
HB_MEAN = float(hb_tr.mean())
HB_STD  = float(hb_tr.std())
hb_tr_n = ((hb_tr - HB_MEAN) / HB_STD).astype("float32")
hb_vl_n = ((hb_vl - HB_MEAN) / HB_STD).astype("float32")
hb_te_n = ((hb_te - HB_MEAN) / HB_STD).astype("float32")
print(f"Hb normalised (z-score) — mean={HB_MEAN:.2f}  std={HB_STD:.2f}")

print("Building datasets (preloading images into RAM) …")
ds_img_tr_balanced = make_balanced_image_ds(p_tr, y_tr_bin, hb_tr_n)
ds_img_vl          = make_image_ds(p_vl, y_vl_bin, hb_vl_n, shuffle=False)
ds_img_te          = make_image_ds(p_te, y_te_bin, hb_te_n, shuffle=False, augment=False)

print("\nDatasets ready — all images in RAM, no Drive I/O during training.")
model_tmp, _ = build_model()
print(f"Backbone     : MobileNetV3Small + CBAM")
print(f"cls_output   : Dense(1, sigmoid) — binary anemia")
print(f"hb_output    : Dense(1, linear)  — Hb estimation")
print(f"Total params : {model_tmp.count_params():,}")
del model_tmp
# Out:
# Binary train: [1018 1441]  (0=Non-Anemic, 1=Anemic)
# Binary val  : [186 345]
# Binary test : [215 319]
# Hb normalised (z-score) — mean=10.38  std=2.31
# Building datasets (preloading images into RAM) …
#
# Datasets ready — all images in RAM, no Drive I/O during training.
# Backbone     : MobileNetV3Small + CBAM
# cls_output   : Dense(1, sigmoid) — binary anemia
# hb_output    : Dense(1, linear)  — Hb estimation
# Total params : 1,164,473

# %%
# Memory-safe dataset hotfix: stream images instead of preloading all into RAM.
# Run this cell once before training/CV cells.

def make_image_ds(paths, labels, hb_values, shuffle=True, augment=None, lazy_load=True):
    if augment is None:
        augment = shuffle

    paths = np.asarray(paths)
    labels = np.asarray(labels).astype("int32")
    hb_values = np.asarray(hb_values).astype("float32")

    # Fallback to lazy mode automatically for larger folds.
    est_bytes = int(len(paths)) * IMG_SIZE * IMG_SIZE * 3 * 4
    force_lazy = est_bytes > (600 * 1024 * 1024)
    use_lazy = lazy_load or force_lazy

    if use_lazy:
        def gen():
            for p, l, h in zip(paths, labels, hb_values):
                img = _load_img_np(p).astype(np.float32)
                yield img, int(l), float(h)

        ds = tf.data.Dataset.from_generator(
            gen,
            output_signature=(
                tf.TensorSpec(shape=(IMG_SIZE, IMG_SIZE, 3), dtype=tf.float32),
                tf.TensorSpec(shape=(), dtype=tf.int32),
                tf.TensorSpec(shape=(), dtype=tf.float32),
            ),
        )
    else:
        imgs_np = _preload_images(paths)
        ds = tf.data.Dataset.from_tensor_slices((
            imgs_np,
            labels,
            hb_values,
        ))

    if augment:
        ds = ds.map(
            lambda img, l, h: (
                preprocess_input(augment_fn(img)),
                {"cls_output": tf.cast(l, tf.float32), "hb_output": tf.expand_dims(h, -1)},
            ),
            num_parallel_calls=tf.data.AUTOTUNE,
        )
    else:
        ds = ds.map(
            lambda img, l, h: (
                preprocess_input(img),
                {"cls_output": tf.cast(l, tf.float32), "hb_output": tf.expand_dims(h, -1)},
            ),
            num_parallel_calls=tf.data.AUTOTUNE,
        )

    if shuffle:
        ds = ds.shuffle(min(256, len(paths)), seed=SEED, reshuffle_each_iteration=True)

    return ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)


def make_balanced_image_ds(paths, labels, hb_values, lazy_load=True):
    df_tmp = pd.DataFrame({"path": paths, "label": labels, "hb": hb_values})
    max_count = df_tmp["label"].value_counts().max()
    df_balanced = pd.concat([
        resample(group, replace=True, n_samples=max_count, random_state=SEED)
        for _, group in df_tmp.groupby("label")
    ], ignore_index=True).sample(frac=1, random_state=SEED).reset_index(drop=True)

    return make_image_ds(
        df_balanced["path"].values,
        df_balanced["label"].values,
        df_balanced["hb"].values,
        shuffle=True,
        lazy_load=lazy_load,
    )

print("Memory-safe dataset hotfix loaded: make_image_ds/make_balanced_image_ds now stream from disk by default.")
# Out:
# Memory-safe dataset hotfix loaded: make_image_ds/make_balanced_image_ds now stream from disk by default.

# %%
# ── Filter: remove images with insufficient usable tissue ─────────────────────
# Must run AFTER _load_img_np is defined (cell above).
# _load_img_np already applies _apply_clahe_np and returns LAB float32.
MIN_TISSUE_PX = 200

def _count_tissue_pixels(path):
    try:
        lab = _load_img_np(path)   # already LAB — do NOT wrap in _apply_clahe_np again
        L   = lab[:, :, 0]
        return int(((L > 40) & (L < 225)).sum())
    except Exception:
        return 0

def _filter_split(paths, *arrays):
    """Return boolean mask, filtered paths, and filtered arrays for one split."""
    mask = np.array([_count_tissue_pixels(p) >= MIN_TISSUE_PX for p in paths])
    return mask, paths[mask], *(a[mask] for a in arrays)

print("Filtering low-quality images from each split …")
mask_tr, p_tr, lbl_tr, hb_tr, y_tr, site_tr = _filter_split(
    p_tr, lbl_tr, hb_tr, y_tr, site_tr)
mask_vl, p_vl, lbl_vl, hb_vl, y_vl, site_vl = _filter_split(
    p_vl, lbl_vl, hb_vl, y_vl, site_vl)
mask_te, p_te, lbl_te, hb_te, y_te, site_te = _filter_split(
    p_te, lbl_te, hb_te, y_te, site_te)

Xnh_tr, Xnh_vl, Xnh_te = Xnh_tr[mask_tr], Xnh_vl[mask_vl], Xnh_te[mask_te]
Xwh_tr, Xwh_vl, Xwh_te = Xwh_tr[mask_tr], Xwh_vl[mask_vl], Xwh_te[mask_te]

print(f"Removed — Train: {(~mask_tr).sum()}  Val: {(~mask_vl).sum()}  Test: {(~mask_te).sum()}")
print(f"Remaining — Train: {len(p_tr)}  Val: {len(p_vl)}  Test: {len(p_te)}")
# Out:
# Filtering low-quality images from each split …
# Removed — Train: 0  Val: 0  Test: 0
# Remaining — Train: 2459  Val: 531  Test: 534

# %%
# ── ROI Signal Check: conjunctiva a* vs Hb ────────────────────────────────────
# _load_img_np already returns LAB — do NOT wrap in _apply_clahe_np again.

def _conjunctiva_a_stat(path):
    """80th-percentile a* over tissue pixels."""
    try:
        lab = _load_img_np(path)   # already LAB float32
        L, A = lab[:, :, 0], lab[:, :, 1]
        tissue_a = A[(L > 40) & (L < 225)]
        if len(tissue_a) < 100:
            return float("nan")
        return float(np.percentile(tissue_a, 80))
    except Exception:
        return float("nan")

print("Computing conjunctiva a* (80th percentile) for 200 training images …")
sample_idx     = np.random.default_rng(SEED).choice(len(p_tr), size=min(200, len(p_tr)), replace=False)
a_vals         = np.array([_conjunctiva_a_stat(p_tr[i]) for i in sample_idx])
hb_vals_sample = hb_tr[sample_idx]

valid = ~np.isnan(a_vals)
r = np.corrcoef(a_vals[valid], hb_vals_sample[valid])[0, 1]

fig, axes = plt.subplots(1, 2, figsize=(11, 4))

axes[0].scatter(a_vals[valid], hb_vals_sample[valid], alpha=0.5, s=20, color="steelblue")
m, b = np.polyfit(a_vals[valid], hb_vals_sample[valid], 1)
xs = np.linspace(a_vals[valid].min(), a_vals[valid].max(), 100)
axes[0].plot(xs, m * xs + b, "r--", lw=1.5, label=f"r = {r:.3f}")
axes[0].set_xlabel("a* 80th percentile (top 20% reddest pixels)")
axes[0].set_ylabel("Hb level (g/dL)")
axes[0].set_title("ROI Signal Check: a* vs Hb")
axes[0].legend()

sample_lab = _load_img_np(p_tr[sample_idx[0]])   # already LAB
axes[1].imshow(sample_lab[:, :, 1], cmap="RdYlGn_r", vmin=110, vmax=175)
axes[1].set_title("a* channel (correct LAB)\nbright=red  dark=pale")
axes[1].axis("off")

plt.tight_layout()
plt.show()

print(f"Pearson r(a* p80, Hb) = {r:.3f}  (valid: {valid.sum()}/200)")
if abs(r) < 0.15:
    print("  CRITICAL: near zero — check heatmap. Is there any red/bright region?")
elif abs(r) < 0.35:
    print("  MODERATE: weak but learnable signal.")
else:
    print("  GOOD: clear signal present.")
# Out:
# Computing conjunctiva a* (80th percentile) for 200 training images …
# Pearson r(a* p80, Hb) = -0.172  (valid: 200/200)
#   MODERATE: weak but learnable signal.

# %%
# ── Age-Group Correlation Test ────────────────────────────────────────────────
# If r improves within a specific age band, the Slow Fusion model is the right
# approach — it means Age is a moderating variable the linear test misses.

age_tr = df_clean.loc[df_clean["base_id"].isin(base_tr), "Age(Months)"].to_numpy()

bands = {
    "6–12 mo":  (6,  12),
    "12–24 mo": (12, 24),
    "24–36 mo": (24, 36),
    "36–60 mo": (36, 60),
    "All":       (0, 999),
}

print(f"{'Band':<12} {'n':>4}  {'r(a*, Hb)':>10}")
print("-" * 32)
for label, (lo, hi) in bands.items():
    mask = (age_tr >= lo) & (age_tr < hi)
    idx  = np.where(mask)[0]
    if len(idx) < 20:
        print(f"{label:<12} {len(idx):>4}  {'too few':>10}")
        continue
    sub_a  = np.array([_conjunctiva_a_stat(p_tr[i]) for i in idx])
    sub_hb = hb_tr[idx]
    valid  = ~np.isnan(sub_a)
    if valid.sum() < 10:
        continue
    r_band = np.corrcoef(sub_a[valid], sub_hb[valid])[0, 1]
    print(f"{label:<12} {valid.sum():>4}  {r_band:>10.3f}")

print()
print("If any band shows |r| > 0.25, the fusion model will leverage Age")
print("to learn group-specific Hb thresholds — that's the non-linear signal.")
# Out:
# Band            n   r(a*, Hb)
# --------------------------------
# 6–12 mo        84      -0.452
# 12–24 mo      642       0.032
# 24–36 mo      511      -0.027
# 36–60 mo      917      -0.119
# All          2459      -0.065
#
# If any band shows |r| > 0.25, the fusion model will leverage Age
# to learn group-specific Hb thresholds — that's the non-linear signal.

# %%
# ── Pearson r Improvement: Raw vs Trimmed vs Site-Normalised ──────────────────
# Compares three versions of the a* feature to show how much signal we recover
# by (a) using tissue-only percentiles and (b) removing per-clinic lighting bias.
from scipy.stats import pearsonr

def _get_tissue_stats(path):
    """Return (a_mean, a_p80, a_trim) from tissue pixels of one image."""
    try:
        lab = _load_img_np(path)   # already LAB float32
        L, A = lab[:, :, 0], lab[:, :, 1]
        tissue_a = A[(L > 40) & (L < 225)].astype(np.float32)
        if len(tissue_a) < 50:
            return (float("nan"),) * 3
        p30, p80 = np.percentile(tissue_a, [30, 80])
        trim = tissue_a[(tissue_a >= p30) & (tissue_a <= np.percentile(tissue_a, 70))]
        return (
            float(np.mean(tissue_a)),
            float(p80),
            float(np.mean(trim)) if len(trim) > 0 else float(np.mean(tissue_a)),
        )
    except Exception:
        return (float("nan"),) * 3

print("Computing tissue a* stats for 200 training samples …")
sample_idx = np.random.default_rng(SEED).choice(len(p_tr), size=min(200, len(p_tr)), replace=False)

rows = [_get_tissue_stats(p_tr[i]) for i in sample_idx]
a_mean_s  = np.array([r[0] for r in rows])
a_p80_s   = np.array([r[1] for r in rows])
a_trim_s  = np.array([r[2] for r in rows])
hb_s      = hb_tr[sample_idx]
site_s    = site_tr[sample_idx]

# Site-normalise using per-site means in this sample
site_means = {s: np.nanmean(a_mean_s[site_s == s]) for s in np.unique(site_s)}
a_norm_s   = a_mean_s - np.array([site_means.get(s, 0) for s in site_s])

results = []
for name, vals in [("a_mean (raw)",      a_mean_s),
                   ("a_p80 (tissue)",     a_p80_s),
                   ("a_trim (p30–p70)",   a_trim_s),
                   ("a_mean site-norm",   a_norm_s)]:
    valid = ~np.isnan(vals)
    if valid.sum() < 20:
        continue
    r, p = pearsonr(vals[valid], hb_s[valid])
    results.append((name, valid.sum(), r, p))

print(f"\n{'Feature':<22} {'n':>4}  {'r':>7}  {'p-val':>9}  signal")
print("-" * 55)
for name, n, r, p in results:
    sig = "strong" if abs(r) > 0.35 else ("moderate" if abs(r) > 0.20 else "weak")
    star = "***" if p < 0.001 else ("**" if p < 0.01 else ("*" if p < 0.05 else ""))
    print(f"{name:<22} {n:>4}  {r:>7.3f}  {p:>9.2e}  {sig} {star}")

# ── Scatter: best feature vs raw ─────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(11, 4))
for ax, (name, vals) in zip(axes, [("a_mean (raw)", a_mean_s),
                                    ("a_mean site-norm", a_norm_s)]):
    valid = ~np.isnan(vals)
    r, _ = pearsonr(vals[valid], hb_s[valid])
    ax.scatter(vals[valid], hb_s[valid], alpha=0.45, s=18, color="steelblue")
    m, b = np.polyfit(vals[valid], hb_s[valid], 1)
    xs = np.linspace(vals[valid].min(), vals[valid].max(), 100)
    ax.plot(xs, m * xs + b, "r--", lw=1.5, label=f"r = {r:.3f}")
    ax.set_xlabel(name); ax.set_ylabel("Hb (g/dL)")
    ax.set_title(name); ax.legend()
plt.suptitle("Pearson r: Raw a* vs Site-Normalised a*", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Computing tissue a* stats for 200 training samples …
#
# Feature                   n        r      p-val  signal
# -------------------------------------------------------
# a_mean (raw)            200   -0.137   5.28e-02  weak
# a_p80 (tissue)          200   -0.172   1.48e-02  weak *
# a_trim (p30–p70)        200   -0.120   9.05e-02  weak
# a_mean site-norm        200   -0.117   9.78e-02  weak

# %% [markdown]
# ### 4.2 · Model Architecture & Training

# %%
import shutil
from sklearn.metrics import roc_auc_score

# ── Compile helper ────────────────────────────────────────────────────────────
# BinaryCrossentropy for sigmoid(1) cls head; Huber for Hb regression.
# Fixed starting weights; AUROC is the primary training signal (not val_loss).
def compile_model(model, lr):
    model.compile(
        optimizer=Adam(lr),
        loss={
            "cls_output": tf.keras.losses.BinaryCrossentropy(),
            "hb_output" : tf.keras.losses.Huber(delta=1.0),
        },
        loss_weights={"cls_output": 1.0, "hb_output": 0.5},
        metrics={
            "cls_output": [
                tf.keras.metrics.BinaryAccuracy(name="accuracy"),
                tf.keras.metrics.AUC(name="auroc"),
            ],
            "hb_output": "mae",
        },
    )

# ── AUROC callback — computes val AUROC after each epoch ─────────────────────
class AUROCCallback(tf.keras.callbacks.Callback):
    def __init__(self, val_ds, y_val_binary):
        super().__init__()
        self.val_ds = val_ds
        self.y_val  = y_val_binary

    def on_epoch_end(self, epoch, logs=None):
        probs = self.model.predict(self.val_ds, verbose=0)["cls_output"].flatten()
        try:
            auroc = roc_auc_score(self.y_val, probs)
        except ValueError:
            auroc = 0.5
        logs["val_auroc"] = auroc

# ── Separate checkpoint paths for each phase ─────────────────────────────────
VISUAL_PATH_P1 = VISUAL_PATH.replace(".keras", "_p1.keras")
VISUAL_PATH_P2 = VISUAL_PATH.replace(".keras", "_p2.keras")

auroc_cb = AUROCCallback(ds_img_vl, y_vl_bin)

# ── Phase 1: unfreeze last 50 backbone layers — repurpose colour filters ──────
# ImageNet filters detect shapes/edges by default. Unfreezing the final 50 layers
# with a small LR forces them to repurpose toward detecting subtle hue shifts.
print("Phase 1 — unfreezing last 50 backbone layers for colour adaptation ...")
visual_model, base_model = build_model()

n_layers = len(base_model.layers)
unfreeze_from = max(0, n_layers - 50)
unfrozen = 0
for layer in base_model.layers[unfreeze_from:]:
    if not isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = True
        unfrozen += 1
print(f"  Unfreezing last 50 of {n_layers} backbone layers  ({unfrozen} trainable)")
compile_model(visual_model, lr=3e-4)

history1 = visual_model.fit(
    ds_img_tr_balanced,
    validation_data=ds_img_vl,
    epochs=25,
    callbacks=[
        auroc_cb,
        ModelCheckpoint(VISUAL_PATH_P1, monitor="val_auroc",
                        mode="max", save_best_only=True, verbose=1),
        EarlyStopping(monitor="val_auroc", mode="max", patience=8,
                      restore_best_weights=True),
        ReduceLROnPlateau(monitor="val_auroc", mode="max", factor=0.5,
                          patience=4, min_lr=1e-6, verbose=1),
    ],
    verbose=1,
)

# ── Phase 2: unfreeze top 25% ─────────────────────────────────────────────────
print("Phase 2 — fine-tuning top 25% of MobileNetV3Small + CBAM ...")
fine_tune_from = int(n_layers * 0.75)

for layer in base_model.layers[fine_tune_from:]:
    if not isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = True
compile_model(visual_model, lr=5e-5)

history2 = visual_model.fit(
    ds_img_tr_balanced,
    validation_data=ds_img_vl,
    epochs=50,
    callbacks=[
        auroc_cb,
        ModelCheckpoint(VISUAL_PATH_P2, monitor="val_auroc",
                        mode="max", save_best_only=True, verbose=1),
        EarlyStopping(monitor="val_auroc", mode="max", patience=12,
                      restore_best_weights=True),
        ReduceLROnPlateau(monitor="val_auroc", mode="max", factor=0.5,
                          patience=5, min_lr=1e-7, verbose=1),
    ],
    verbose=1,
)

# ── Keep best of Phase 1 / Phase 2 (by val_auroc) ────────────────────────────
best_p1_auroc = max(history1.history.get("val_auroc", [0.5]))
best_p2_auroc = max(history2.history.get("val_auroc", [0.5]))
winner = VISUAL_PATH_P1 if best_p1_auroc >= best_p2_auroc else VISUAL_PATH_P2
shutil.copy(winner, VISUAL_PATH)
print(f"Phase 1 best val_auroc : {best_p1_auroc:.4f}")
print(f"Phase 2 best val_auroc : {best_p2_auroc:.4f}")
print(f"Saved best phase → {VISUAL_PATH}")
# Out:
# Phase 1 — unfreezing last 50 backbone layers for colour adaptation ...
#   Unfreezing last 50 of 157 backbone layers  (39 trainable)
# Epoch 1/25
#      91/Unknown 179s 1s/step - cls_output_accuracy: 0.5131 - cls_output_auroc: 0.5273 - cls_output_loss: 0.7521 - hb_output_loss: 0.5954 - hb_output_mae: 0.9885 - loss: 1.1157
# Epoch 1: val_auroc improved from None to 0.53419, saving model to G:\My Drive\Capstone\Bari\Notebook\models\visual_model_best_p1.keras
#
# Epoch 1: finished saving model to G:\My Drive\Capstone\Bari\Notebook\models\visual_model_best_p1.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - cls_output_accuracy: 0.5409 - cls_output_auroc: 0.5517 - cls_output_loss: 0.7075 - hb_output_loss: 0.5183 - hb_output_mae: 0.9149 - loss: 1.0458 - val_cls_output_accuracy: 0.5744 - val_cls_output_auroc: 0.5522 - val_cls_output_loss: 0.6510 - val_hb_output_loss: 0.3250 - val_hb_output_mae: 0.7058 - val_loss: 0.9258 - val_auroc: 0.5342 - learning_rate: 3.0000e-04
# Epoch 2/25
# ...

# %%
acc   = (history1.history['cls_output_accuracy']
       + history2.history['cls_output_accuracy'])
vacc  = (history1.history['val_cls_output_accuracy']
       + history2.history['val_cls_output_accuracy'])
loss  = history1.history['loss']  + history2.history['loss']
vloss = history1.history['val_loss'] + history2.history['val_loss']

# AUROC from AUROCCallback (logged as 'val_auroc')
auroc_p1 = history1.history.get('val_auroc', [])
auroc_p2 = history2.history.get('val_auroc', [])
auroc_all = auroc_p1 + auroc_p2

b1 = len(history1.history['loss'])

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Accuracy
axes[0].plot(acc,  label='Train'); axes[0].plot(vacc, label='Val')
axes[0].axvline(b1 - 1, color='gray', linestyle='--', alpha=0.7, label='Phase 2 start')
axes[0].set_title('Binary Accuracy'); axes[0].set_xlabel('Epoch')
axes[0].legend(); axes[0].grid(alpha=0.3)

# Total loss
axes[1].plot(loss,  label='Train'); axes[1].plot(vloss, label='Val')
axes[1].axvline(b1 - 1, color='gray', linestyle='--', alpha=0.7, label='Phase 2 start')
axes[1].set_title('Total Loss'); axes[1].set_xlabel('Epoch')
axes[1].legend(); axes[1].grid(alpha=0.3)

# AUROC
if auroc_all:
    axes[2].plot(auroc_all, label='Val AUROC', color='darkorange')
    axes[2].axvline(b1 - 1, color='gray', linestyle='--', alpha=0.7, label='Phase 2 start')
    axes[2].axhline(0.5, color='black', linestyle=':', alpha=0.4, label='Random')
    axes[2].set_title('Validation AUROC'); axes[2].set_xlabel('Epoch')
    axes[2].set_ylim(0.4, 1.0); axes[2].legend(); axes[2].grid(alpha=0.3)

plt.suptitle('MobileNetV3Small + CBAM — Phase 1 (frozen) / Phase 2 (top 25% unfrozen)',
             fontsize=12, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, 'visual_training_history.png'), dpi=120)
plt.show()

print(f"Phase 1 best val_acc   : {max(history1.history['val_cls_output_accuracy']):.4f}")
print(f"Phase 2 best val_acc   : {max(history2.history['val_cls_output_accuracy']):.4f}")
if auroc_p1: print(f"Phase 1 best val_auroc : {max(auroc_p1):.4f}")
if auroc_p2: print(f"Phase 2 best val_auroc : {max(auroc_p2):.4f}")
# Out:
# Phase 1 best val_acc   : 0.7759
# Phase 2 best val_acc   : 0.7872
# Phase 1 best val_auroc : 0.8167
# Phase 2 best val_auroc : 0.8301

# %% [markdown]
# ### 4.3 · TTA Evaluation (Test-Time Augmentation)
#
# 8 augmented + 1 clean inference pass, averaged for robust test predictions. Reports binary classification metrics and Hb regression metrics (MAE, RMSE, R²).

# %%
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, roc_auc_score, roc_curve

# Define custom layer for deserialization
@tf.keras.utils.register_keras_serializable(package="custom")
class MCDropout(tf.keras.layers.Dropout):
    """Dropout active at inference for uncertainty estimation."""
    def call(self, inputs, training=None):
        return super().call(inputs, training=True)

def predict_tta(model, paths, labels, hb_values, n_aug=8):
    """
    TTA: average anemic probability over n_aug augmented + 1 clean pass.
    Optimized for speed by preloading test images once and reusing them.
    """
    paths = np.asarray(paths)
    labels = np.asarray(labels)
    hb_values = np.asarray(hb_values)

    if not (len(paths) == len(labels) == len(hb_values)):
        raise ValueError("paths, labels, and hb_values must have the same length")

    # Heavy PIL+CLAHE preprocessing is done once here instead of every TTA pass.
    imgs_np = _preload_images(paths).astype(np.float32)

    def _make_predict_ds(images_np, augment):
        ds = tf.data.Dataset.from_tensor_slices(images_np)
        if augment:
            ds = ds.map(
                lambda img: preprocess_input(augment_fn(img)),
                num_parallel_calls=tf.data.AUTOTUNE,
            )
        else:
            ds = ds.map(
                lambda img: preprocess_input(img),
                num_parallel_calls=tf.data.AUTOTUNE,
            )
        return ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    def _extract_cls_hb(out_dict):
        cls_out = np.asarray(out_dict["cls_output"])
        if cls_out.ndim == 2 and cls_out.shape[1] == 2:
            cls_out = tf.nn.softmax(cls_out, axis=-1)[:, 1].numpy()
        else:
            cls_out = cls_out.flatten()
        hb_out = np.asarray(out_dict["hb_output"]).flatten()
        return cls_out, hb_out

    cls_stack, hb_stack = [], []

    for _ in range(n_aug):
        ds_aug = _make_predict_ds(imgs_np, augment=True)
        out = model.predict(ds_aug, verbose=0)
        cls_out, hb_out = _extract_cls_hb(out)
        cls_stack.append(cls_out)
        hb_stack.append(hb_out)

    ds_clean = _make_predict_ds(imgs_np, augment=False)
    out_clean = model.predict(ds_clean, verbose=0)
    cls_out, hb_out = _extract_cls_hb(out_clean)
    cls_stack.append(cls_out)
    hb_stack.append(hb_out)

    return np.mean(cls_stack, axis=0), np.mean(hb_stack, axis=0)

# Keras 3 Lambda deserialization limitation: fallback to in-memory model if needed
custom_objects = {"MCDropout": MCDropout}
try:
    best_visual_model = tf.keras.models.load_model(VISUAL_PATH, compile=False, safe_mode=False, custom_objects=custom_objects)
except (TypeError, NotImplementedError):
    try:
        tf.keras.config.enable_unsafe_deserialization()
        best_visual_model = tf.keras.models.load_model(VISUAL_PATH, compile=False, custom_objects=custom_objects)
    except (TypeError, NotImplementedError):
        # Keras 3 cannot deserialize model from disk; use in-memory checkpoint
        for model_name in ("best_visual_model", "visual_model", "base_model"):
            m = globals().get(model_name)
            if isinstance(m, tf.keras.Model):
                print(f"⚠ Using in-memory '{model_name}' after Keras 3 deserialization failed for VISUAL_PATH.")
                best_visual_model = m
                break
        else:
            raise RuntimeError("Could not load VISUAL_PATH and no in-memory model fallback available.")

print("Predicting with TTA (8 augmented + 1 clean) …")
p_anemic_scores, hb_preds_n = predict_tta(best_visual_model, p_te, y_te_bin, hb_te_n, n_aug=8)

# Sigmoid → binary label at threshold 0.5
cls_preds = (p_anemic_scores >= 0.5).astype(int)

# Denormalise Hb (z-score → g/dL)
hb_preds = p_anemic_scores * 0  # placeholder; use hb_preds_n below
hb_preds = hb_preds_n * HB_STD + HB_MEAN

print("CLASSIFICATION  (Non-Anemic vs Anemic)")
print(f"Accuracy  : {accuracy_score(y_te_bin, cls_preds):.4f}")
print(f"Macro F1  : {f1_score(y_te_bin, cls_preds, average='macro', zero_division=0):.4f}")

try:
    auroc = roc_auc_score(y_te_bin, p_anemic_scores)
    print(f"AUROC     : {auroc:.4f}")
    # Sensitivity at 90% specificity
    fpr, tpr, _ = roc_curve(y_te_bin, p_anemic_scores)
    idx90 = np.argmin(np.abs(fpr - 0.10))
    print(f"Sensitivity @ 90% specificity : {tpr[idx90]:.3f}")
except ValueError:
    pass

print(classification_report(y_te_bin, cls_preds,
                             target_names=VISUAL_CLASS_NAMES, zero_division=0))

cm = confusion_matrix(y_te_bin, cls_preds)
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=VISUAL_CLASS_NAMES, yticklabels=VISUAL_CLASS_NAMES)
plt.title("Visual CNN + TTA — Binary Classification")
plt.ylabel("True"); plt.xlabel("Predicted")
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "visual_confusion_matrix.png"), dpi=120)
plt.show()

print("REGRESSION  (Hb level estimation, g/dL)")
mae  = mean_absolute_error(hb_te, hb_preds)
rmse = np.sqrt(mean_squared_error(hb_te, hb_preds))
r2   = r2_score(hb_te, hb_preds)
print(f"MAE  : {mae:.3f} g/dL")
print(f"RMSE : {rmse:.3f} g/dL")
print(f"R²   : {r2:.4f}")

fig, ax = plt.subplots(figsize=(6, 5))
ax.scatter(hb_te, hb_preds, alpha=0.5, s=20)
lims = [min(hb_te.min(), hb_preds.min()), max(hb_te.max(), hb_preds.max())]
ax.plot(lims, lims, "r--", lw=1)
ax.set_xlabel("True Hb (g/dL)"); ax.set_ylabel("Predicted Hb (g/dL)")
ax.set_title(f"Hb Regression  MAE={mae:.2f}  R²={r2:.3f}")
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "hb_regression.png"), dpi=120)
plt.show()

# Derive severity from predicted Hb using WHO thresholds + age/gender
ages_te    = df_clean["Age(Months)"].to_numpy()[idx_te]
genders_te = df_clean["GENDER"].to_numpy()[idx_te]

sev_from_hb = np.array([
    CLASS_MAP.get(anemia_label(hb, age, g), -1)
    for hb, age, g in zip(hb_preds, ages_te, genders_te)
])
valid = sev_from_hb >= 0

print("\nSeverity from estimated Hb (WHO thresholds) vs true WHO labels:")
print(f"  Accuracy : {accuracy_score(y_te[valid], sev_from_hb[valid]):.4f}")
print(f"  Macro F1 : {f1_score(y_te[valid], sev_from_hb[valid], average='macro', zero_division=0):.4f}")

# Severe anemia sensitivity (most clinically critical)
severe_mask = (y_te == 3)
if severe_mask.sum() > 0 and valid.sum() > 0:
    sev_preds_mask = sev_from_hb[valid] == 3
    true_sev_mask  = y_te[valid] == 3
    sev_sens = sev_preds_mask[true_sev_mask].sum() / true_sev_mask.sum() if true_sev_mask.sum() > 0 else 0.0
    print(f"  Severe anemia sensitivity : {sev_sens:.3f}  (n={true_sev_mask.sum()})")

print(classification_report(y_te[valid], sev_from_hb[valid],
                             target_names=CLASS_NAMES, zero_division=0))
# Out:
# ⚠ Using in-memory 'visual_model' after Keras 3 deserialization failed for VISUAL_PATH.
# Predicting with TTA (8 augmented + 1 clean) …
# CLASSIFICATION  (Non-Anemic vs Anemic)
# Accuracy  : 0.6966
# Macro F1  : 0.6842
# AUROC     : 0.7526
# Sensitivity @ 90% specificity : 0.423
#               precision    recall  f1-score   support
#
#   Non-Anemic       0.62      0.62      0.62       215
#       Anemic       0.74      0.75      0.75       319
#
#     accuracy                           0.70       534
#    macro avg       0.68      0.68      0.68       534
# weighted avg       0.70      0.70      0.70       534
# REGRESSION  (Hb level estimation, g/dL)
# MAE  : 1.746 g/dL
# RMSE : 2.217 g/dL
# R²   : 0.0113
# Severity from estimated Hb (WHO thresholds) vs true WHO labels:
#   Accuracy : 0.4307
#   Macro F1 : 0.3040
#   Severe anemia sensitivity : 0.000  (n=35)
#               precision    recall  f1-score   support
#
#       Normal       0.66      0.59      0.62       225
# ...

# %% [markdown]
# ### 4.3 · Grad-CAM Interpretability
#
# Gradient-weighted Class Activation Mapping (Grad-CAM) highlights which regions of the conjunctiva drive the model's prediction. Expected behaviour: activation concentrated over the red palpebral tissue.

# %%
import cv2


def get_gradcam(model, img_array, pred_index=None):
   
    # ── 1. Find last conv layer in the model for Grad-CAM ───────────────────────
    # Works regardless of whether backbone is a sub-model or flattened layers
    last_conv_layer = None
    for layer in reversed(model.layers):
        if isinstance(layer, tf.keras.layers.Conv2D) or            (hasattr(layer, 'layers') and
            any(isinstance(l, tf.keras.layers.Conv2D) for l in layer.layers)):
            last_conv_layer = layer
            break

    if last_conv_layer is None:
        raise ValueError("No conv layer found in model.")

    # ── 2. Build grad model: inputs → [last_conv_output, cls_output] ──────────
    grad_model = tf.keras.Model(
        inputs=model.inputs,
        outputs=[last_conv_layer.output, model.output["cls_output"]]
    )

    # ── 3. GradientTape ───────────────────────────────────────────────────────
    img_t = tf.cast(img_array, tf.float32)
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_t, training=False)
        tape.watch(conv_outputs)
        if pred_index is None:
            pred_index = int(tf.argmax(predictions[0]))
        score = predictions[:, pred_index]

    grads   = tape.gradient(score, conv_outputs)
    pooled  = tf.reduce_mean(grads, axis=(0, 1, 2))
    heatmap = tf.reduce_sum(conv_outputs[0] * pooled, axis=-1)
    heatmap = tf.maximum(heatmap, 0)
    heatmap = (heatmap / (tf.reduce_max(heatmap) + 1e-8)).numpy()

    heatmap_resized = cv2.resize(heatmap, (IMG_SIZE, IMG_SIZE))
    heatmap_u8      = np.uint8(255 * heatmap_resized)
    colormap        = cv2.applyColorMap(heatmap_u8, cv2.COLORMAP_JET)
    return cv2.cvtColor(colormap, cv2.COLOR_BGR2RGB), heatmap_resized


print("Grad-CAM helper ready (nested MobileNetV3Small).")
# Out:
# Grad-CAM helper ready (nested MobileNetV3Small).

# %%
# ── Grad-CAM visualisation: one sample per binary class ───────────────────────
# Load best model if not already in memory
if "best_visual_model" not in dir():
    best_visual_model = tf.keras.models.load_model(VISUAL_PATH, compile=False)
    print(f"Loaded model from {VISUAL_PATH}")
CLASS_LABELS_BIN = ["Non-Anemic", "Anemic"]
sampled_idx = []
for cls in range(NUM_VISUAL):
    hits = np.where(y_te_bin == cls)[0]
    if len(hits):
        sampled_idx.append(hits[0])

N_SAMPLES = len(sampled_idx)
fig, axes = plt.subplots(N_SAMPLES, 3, figsize=(12, 4 * N_SAMPLES))
if N_SAMPLES == 1:
    axes = axes[np.newaxis]
COL_TITLES = ["Original", "Heatmap", "Overlay"]

for row, i in enumerate(sampled_idx):
    path     = p_te[i]
    true_cls = CLASS_LABELS_BIN[y_te_bin[i]]
    img_t    = load_and_preprocess(path)
    img_a    = tf.expand_dims(img_t, 0)

    try:
        heatmap_rgb, _ = get_gradcam(best_visual_model, img_a)
        orig = np.array(Image.open(path).convert("RGB").resize((IMG_SIZE, IMG_SIZE))) / 255.0
        over = np.clip(orig + 0.4 * heatmap_rgb / 255.0, 0, 1)
    except Exception as e:
        orig = np.array(Image.open(path).convert("RGB").resize((IMG_SIZE, IMG_SIZE))) / 255.0
        heatmap_rgb = np.zeros((IMG_SIZE, IMG_SIZE, 3), dtype=np.uint8)
        over = orig
        print(f"Grad-CAM failed for sample {i}: {e}")

    # Predict (handle dict output from multi-task model)
    out = best_visual_model.predict(img_a, verbose=0)
    probs    = out["cls_output"][0] if isinstance(out, dict) else out[0]
    pred_idx = int(np.argmax(probs))
    conf     = float(probs[pred_idx])
    pred_cls = CLASS_LABELS_BIN[pred_idx]

    for col, data in enumerate([orig, heatmap_rgb / 255.0, over]):
        ax = axes[row, col]
        ax.imshow(np.clip(data, 0, 1))
        ax.axis("off")
        if row == 0:
            ax.set_title(COL_TITLES[col], fontsize=11, fontweight="bold")
    axes[row, 0].set_ylabel(f"True: {true_cls}", fontsize=9, fontweight="bold")
    axes[row, 2].set_title(f"Pred: {pred_cls} ({conf:.2f})", fontsize=9)

plt.suptitle("Grad-CAM — MobileNetV3Small Attention on Conjunctiva",
             fontsize=14, fontweight="bold")
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "gradcam.png"), dpi=150)
plt.show()

# %% [markdown]
# ### 4.5 · 5-Fold Cross-Validation
#
# Stratified 5-fold CV on the full training set. Each fold runs the same 3-phase progressive unfreeze schedule and reports binary accuracy, macro F1, and Hb MAE.

# %%
# --- 5-Fold CV: MobileNetV3Small + CBAM, two-phase per fold ------------------
skf_vis = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
cv_rows = []

# Ensure custom layers can always be deserialized from .keras checkpoints
cv_custom_objects = {
    "_ChanMeanPool": _ChanMeanPool,
    "_ChanMaxPool": _ChanMaxPool,
    "MCDropout": MCDropout,
}

for fold, (tr_idx, vl_idx) in enumerate(skf_vis.split(p_tr, lbl_tr), 1):
    counts_tr = np.bincount(lbl_tr[tr_idx], minlength=2)
    counts_vl = np.bincount(lbl_tr[vl_idx], minlength=2)
    print(f"\nFold {fold}/5  (train={len(tr_idx)}, val={len(vl_idx)})")
    print(f"  Class dist — train: NA={counts_tr[0]} A={counts_tr[1]}  |  val: NA={counts_vl[0]} A={counts_vl[1]}")

    # Use lazy loading for CV folds to avoid RAM spikes
    ds_f_tr = make_balanced_image_ds(p_tr[tr_idx], lbl_tr[tr_idx], hb_tr[tr_idx], lazy_load=True)
    ds_f_vl = make_image_ds(p_tr[vl_idx], lbl_tr[vl_idx], hb_tr[vl_idx], shuffle=False, lazy_load=True)
    fold_path = os.path.join(MODELS_DIR, f"visual_fold{fold}.keras")
    auroc_fold_cb = AUROCCallback(ds_f_vl, lbl_tr[vl_idx])

    # Phase 1: frozen backbone
    m, base_m = build_model()
    compile_model(m, lr=3e-4)
    m.fit(
        ds_f_tr,
        validation_data=ds_f_vl,
        epochs=20,
        callbacks=[
            auroc_fold_cb,
            EarlyStopping(monitor="val_auroc", mode="max", patience=5, restore_best_weights=True),
            ReduceLROnPlateau(monitor="val_auroc", mode="max", factor=0.5, patience=4, min_lr=1e-6),
        ],
        verbose=0,
    )

    # Phase 2: unfreeze top 25% of backbone (keep BN layers frozen)
    n_layers = len(base_m.layers)
    for layer in base_m.layers[int(n_layers * 0.75):]:
        if not isinstance(layer, tf.keras.layers.BatchNormalization):
            layer.trainable = True
    compile_model(m, lr=3e-6)
    m.fit(
        ds_f_tr,
        validation_data=ds_f_vl,
        epochs=25,
        callbacks=[
            auroc_fold_cb,
            EarlyStopping(monitor="val_auroc", mode="max", patience=5, restore_best_weights=True),
            ModelCheckpoint(fold_path, monitor="val_auroc", mode="max", save_best_only=True),
            ReduceLROnPlateau(monitor="val_auroc", mode="max", factor=0.5, patience=4, min_lr=1e-6),
        ],
        verbose=0,
    )

    m = tf.keras.models.load_model(fold_path, compile=False, custom_objects=cv_custom_objects)
    out = m.predict(ds_f_vl, verbose=0)
    probs = out["cls_output"].flatten()   # sigmoid probabilities
    preds = (probs >= 0.5).astype(int)
    acc = accuracy_score(lbl_tr[vl_idx], preds)
    f1_mac = f1_score(lbl_tr[vl_idx], preds, average="macro", zero_division=0)
    hb_pred = out["hb_output"].flatten() * HB_STD + HB_MEAN
    mae = mean_absolute_error(hb_tr[vl_idx], hb_pred)
    try:
        fold_auroc = roc_auc_score(lbl_tr[vl_idx], probs)
    except ValueError:
        fold_auroc = 0.5

    cv_rows.append({"fold": fold, "accuracy": acc, "f1_macro": f1_mac, "auroc": fold_auroc, "hb_mae": mae})
    print(f"  Accuracy: {acc:.4f}  |  F1: {f1_mac:.4f}  |  AUROC: {fold_auroc:.4f}  |  Hb MAE: {mae:.3f} g/dL")

df_cv_vis = pd.DataFrame(cv_rows)
print("\n-- CV Summary (Binary: Non-Anemic vs Anemic) --")
print(df_cv_vis.to_string(index=False))
print(f"\nMean Acc    : {df_cv_vis['accuracy'].mean():.4f} +- {df_cv_vis['accuracy'].std():.4f}")
print(f"Mean F1     : {df_cv_vis['f1_macro'].mean():.4f} +- {df_cv_vis['f1_macro'].std():.4f}")
print(f"Mean AUROC  : {df_cv_vis['auroc'].mean():.4f} +- {df_cv_vis['auroc'].std():.4f}")
print(f"Mean Hb MAE : {df_cv_vis['hb_mae'].mean():.3f} +- {df_cv_vis['hb_mae'].std():.3f} g/dL")
df_cv_vis.to_csv(os.path.join(RESULTS_DIR, "visual_cv_summary.csv"), index=False)
# Out:
# Fold 1/5  (train=1967, val=492)
#   Class dist — train: NA=815 A=1152  |  val: NA=203 A=289
#   Accuracy: 0.6972  |  F1: 0.6924  |  AUROC: 0.7517  |  Hb MAE: 24.167 g/dL
#
# Fold 2/5  (train=1967, val=492)
#   Class dist — train: NA=814 A=1153  |  val: NA=204 A=288
#   Accuracy: 0.7114  |  F1: 0.7051  |  AUROC: 0.7685  |  Hb MAE: 25.070 g/dL
#
# Fold 3/5  (train=1967, val=492)
#   Class dist — train: NA=814 A=1153  |  val: NA=204 A=288
#   Accuracy: 0.6606  |  F1: 0.6603  |  AUROC: 0.7568  |  Hb MAE: 25.765 g/dL
#
# Fold 4/5  (train=1967, val=492)
#   Class dist — train: NA=814 A=1153  |  val: NA=204 A=288
#   Accuracy: 0.7114  |  F1: 0.7081  |  AUROC: 0.7801  |  Hb MAE: 25.327 g/dL
#
# Fold 5/5  (train=1968, val=491)
#   Class dist — train: NA=815 A=1153  |  val: NA=203 A=288
#   Accuracy: 0.7271  |  F1: 0.7182  |  AUROC: 0.7977  |  Hb MAE: 24.903 g/dL
#
# -- CV Summary (Binary: Non-Anemic vs Anemic) --
#  fold  accuracy  f1_macro    auroc    hb_mae
# ...

# %% [markdown]
# ---
# ## Stage 2 & 3 · Feature Fusion → Tabular Classifier — "The Doctor"
#
# ### Stage 2 · Feature Fusion Layer
#
# Glues Stage 1's visual biomarkers with the patient's clinical context into a single **Patient Profile Vector**.
#
# | Feature | Source | Clinical rationale |
# |---------|--------|--------------------|
# | `hb_est` | Stage 1 CNN regression | Primary severity signal |
# | `P(Anemic)` | Stage 1 CNN classification | Binary detection confidence |
# | `Age(Months)` | Patient record | WHO Hb thresholds change at 24 months |
# | `Gender_F` | Patient record | Biological baseline Hb variance |
# | `Site_ID` | Collection site | Accounts for camera/lighting differences across clinics |
#
# ### Stage 3 · Tabular Classifier (Random Forest)
#
# The RF acts as the **Doctor**: given the full Patient Profile Vector it makes the final diagnostic call.
#
# **Why Random Forest?** Naturally handles the non-linear age-dependent WHO thresholds (e.g., `if Age < 24 and Hb < 7.0 → Severe`) without feature engineering.
#
# | Output class | Label | Clinical meaning |
# |-------------|-------|-----------------|
# | 0 | Normal | Non-Anemic |
# | 1 | Mild | Mild Anemia |
# | 2 | Moderate | Moderate Anemia |
# | 3 | Severe | Severe Anemia |

# %% [markdown]
# ### 5.1 · Fusion Dataset Preparation
#
# Remap 4-class labels to 3 classes for the fusion model: **Normal + Mild → 0**, Moderate → 1, Severe → 2. Compute balanced sample weights to address the severe class imbalance (Severe: n≈166, weight≈5×).

# %%
# ── Ordinal 3-class labels for fusion model ───────────────────────────────────
# Normal→0, Mild→0 (merge: WHO thresholds place Normal/Mild within 1 g/dL,
# making the boundary unlearnable from images), Moderate→1, Severe→2.
# This eliminates the impossible Normal/Mild boundary and creates a clinically
# meaningful ordered scale: No Anemia | Mild-Moderate | Severe.
ORDINAL_REMAP   = np.array([0, 0, 1, 2], dtype=np.int32)   # index into CLASS_NAMES
ORDINAL_NAMES   = ["No Anemia", "Mild-Moderate", "Severe"]
ORDINAL_CLASSES = 3   # K classes → K-1 sigmoid outputs for CORAL

y3_tr = ORDINAL_REMAP[y_tr]
y3_vl = ORDINAL_REMAP[y_vl]
y3_te = ORDINAL_REMAP[y_te]

print("Ordinal 3-class distribution:")
for i, name in enumerate(ORDINAL_NAMES):
    print(f"  {i} {name:14s}  train={np.sum(y3_tr==i):4d}  val={np.sum(y3_vl==i):3d}  test={np.sum(y3_te==i):3d}")

# ── CORAL loss (Consistent Rank Logits) ───────────────────────────────────────
# Model outputs K-1=2 sigmoid values: [P(rank≥1), P(rank≥2)].
# Converts ordinal problem to K-1 binary classification tasks.
def coral_loss(y_true, y_pred):
    K     = y_pred.shape[-1] + 1                       # number of classes
    # Expand target: y_ord[i,k] = 1 if y_true[i] > k  (i.e. rank > k)
    y_ord = tf.cast(
        tf.expand_dims(tf.cast(y_true, tf.int32), 1) >
        tf.range(K - 1, dtype=tf.int32),
        tf.float32)
    return tf.reduce_mean(
        tf.keras.losses.binary_crossentropy(y_ord, y_pred))

def coral_predict(sigmoid_out):
    """Convert K-1 sigmoid outputs to integer class labels."""
    return tf.reduce_sum(tf.cast(sigmoid_out > 0.5, tf.int32), axis=-1)

# ── Fusion model uses ordinal 3-class labels ──────────────────────────────────
FUSION_CLASS_NAMES  = ORDINAL_NAMES
FUSION_NUM_CLASSES  = ORDINAL_CLASSES

cw3_vals = compute_class_weight("balanced", classes=np.arange(FUSION_NUM_CLASSES), y=y3_tr)
cw3_vals = np.sqrt(cw3_vals)
cw3_vals = cw3_vals / cw3_vals.min()
class_weights_3 = dict(enumerate(cw3_vals.astype("float32")))
print("\nOrdinal 3-class soft weights:")
for i, name in enumerate(ORDINAL_NAMES):
    print(f"  {i} {name:14s}  weight={class_weights_3[i]:.3f}")

# ── Balanced oversampling for fusion training (on ordinal labels) ─────────────
_fdf = pd.DataFrame({"path": p_tr, "label": y3_tr, "hb": hb_tr_n,
                     "site": site_tr, "band": band_tr})
for _i in range(Xnh_tr.shape[1]):
    _fdf[f"t{_i}"] = Xnh_tr[:, _i]

_max_c = _fdf["label"].value_counts().max()
_fdf_bal = pd.concat([
    resample(grp, replace=True, n_samples=_max_c, random_state=SEED)
    for _, grp in _fdf.groupby("label")
], ignore_index=True).sample(frac=1, random_state=SEED).reset_index(drop=True)

_tcols   = [f"t{i}" for i in range(Xnh_tr.shape[1])]
p_tr_b   = _fdf_bal["path"].values
Xnh_tr_b = _fdf_bal[_tcols].values.astype("float32")
s_tr_b   = _fdf_bal["site"].values.astype("int32")
bd_tr_b  = _fdf_bal["band"].values.astype("int32")
y_tr_b   = _fdf_bal["label"].values.astype("int32")   # ordinal labels
hb_tr_b  = _fdf_bal["hb"].values.astype("float32")

print("\nBalanced ordinal 3-class distribution (training):")
for i, name in enumerate(ORDINAL_NAMES):
    print(f"  {i} {name:14s} {np.sum(y_tr_b==i):4d}  (was {np.sum(y3_tr==i):4d})")

# ── make_fusion_ds (updated for ordinal labels) ───────────────────────────────
def make_fusion_ds(img_paths, X_tab, site_ids, band_ids, y_labels, hb_norm,
                   augment=True, shuffle=True, sample_weight_map=None):
    """tf.data pipeline for the fusion model.
    Inputs:  image + tabular (FEAT_NO_HB) + site_id + band_id
    Outputs: cls_output (CORAL K-1 sigmoid) + hb_output (z-score Hb)
    """
    print(f"  Preloading {len(img_paths)} images …")
    imgs_np = _preload_images(img_paths)

    if sample_weight_map is not None:
        sw = np.array([sample_weight_map[int(l)] for l in y_labels], dtype="float32")
    else:
        sw = np.ones(len(y_labels), dtype="float32")

    ds = tf.data.Dataset.from_tensor_slices((
        imgs_np,
        X_tab.astype("float32"),
        site_ids.astype("int32"),
        band_ids.astype("int32"),
        y_labels.astype("int32"),
        hb_norm.astype("float32"),
        sw,
    ))
    if augment:
        ds = ds.map(
            lambda img, tab, site, band, l, h, w: (
                {"image_input": preprocess_input(augment_fn(img)),
                 "tab_input":   tab,
                 "site_input":  tf.expand_dims(site, -1),
                 "band_input":  tf.expand_dims(band, -1)},
                {"cls_output": tf.cast(l, tf.int32),
                 "hb_output":  tf.expand_dims(h, -1)},
                w,
            ),
            num_parallel_calls=tf.data.AUTOTUNE,
        )
    else:
        ds = ds.map(
            lambda img, tab, site, band, l, h, w: (
                {"image_input": preprocess_input(img),
                 "tab_input":   tab,
                 "site_input":  tf.expand_dims(site, -1),
                 "band_input":  tf.expand_dims(band, -1)},
                {"cls_output": tf.cast(l, tf.int32),
                 "hb_output":  tf.expand_dims(h, -1)},
                w,
            ),
            num_parallel_calls=tf.data.AUTOTUNE,
        )
    if shuffle:
        ds = ds.shuffle(512, seed=SEED, reshuffle_each_iteration=True)
    return ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

print("\nBuilding fusion datasets …")
ds_mm_tr = make_fusion_ds(p_tr_b, Xnh_tr_b, s_tr_b, bd_tr_b, y_tr_b, hb_tr_b,
                           augment=True,  shuffle=True,  sample_weight_map=class_weights_3)
ds_mm_vl = make_fusion_ds(p_vl, Xnh_vl, site_vl, band_vl, y3_vl, hb_vl_n,
                           augment=False, shuffle=False)
print("Fusion datasets ready.")
# Out:
# Ordinal 3-class distribution:
#   0 No Anemia       train=1565  val=331  test=340
#   1 Mild-Moderate   train= 714  val=180  test=159
#   2 Severe          train= 180  val= 20  test= 35
#
# Ordinal 3-class soft weights:
#   0 No Anemia       weight=1.000
#   1 Mild-Moderate   weight=1.480
#   2 Severe          weight=2.949
#
# Balanced ordinal 3-class distribution (training):
#   0 No Anemia      1565  (was 1565)
#   1 Mild-Moderate  1565  (was  714)
#   2 Severe         1565  (was  180)
#
# Building fusion datasets …
#   Preloading 4695 images …
#   Preloading … 4695/4695
#   Preloading 531 images …
#   Preloading … 531/531
# Fusion datasets ready.

# %% [markdown]
# ### Stage 2 · Feature Fusion + Stage 3 · RF Classifier
#
# **Pipeline:** Image → Stage 1 CNN → `[hb_est, P(Anemic)]` + `[Age, Gender_F, Site_ID]` → RF → 4-class severity.
#
# The `Site_ID` feature lets the RF correct for systematic Hb estimation bias caused by different lighting and camera hardware across collection hospitals.

# %%
# -- Stage 3: Tabular Classifier -- "The Doctor" --------------------------------
# Input vector (5 features):
#   hb_est      - Predicted Hb (g/dL) from Stage 1 CNN  [primary severity signal]
#   P(Anemic)   - Anemia probability from Stage 1 CNN    [binary confidence]
#   Age(Months) - Patient age                            [WHO thresholds are age-dependent]
#   Gender_F    - Biological sex                         [baseline Hb variance]
#   Site_ID     - Collection site (hospital)             [camera/lighting variance]

RF_VIS_PKL = os.path.join(MODELS_DIR, "rf_visual_pipeline.pkl")


def _ensure_visual_custom_layers_registered():
    """Ensure custom layers used by VISUAL_PATH are available for deserialization."""
    if "_ChanMeanPool" not in globals():
        @tf.keras.utils.register_keras_serializable(package="custom")
        class _ChanMeanPool(tf.keras.layers.Layer):
            def call(self, x):
                return tf.reduce_mean(x, axis=-1, keepdims=True)
        globals()["_ChanMeanPool"] = _ChanMeanPool

    if "_ChanMaxPool" not in globals():
        @tf.keras.utils.register_keras_serializable(package="custom")
        class _ChanMaxPool(tf.keras.layers.Layer):
            def call(self, x):
                return tf.reduce_max(x, axis=-1, keepdims=True)
        globals()["_ChanMaxPool"] = _ChanMaxPool

    if "MCDropout" not in globals():
        @tf.keras.utils.register_keras_serializable(package="custom")
        class MCDropout(tf.keras.layers.Dropout):
            def call(self, inputs, training=None):
                return super().call(inputs, training=True)
        globals()["MCDropout"] = MCDropout


def _load_visual_backbone(path):
    _ensure_visual_custom_layers_registered()
    custom_objects = {
        "_ChanMeanPool": globals()["_ChanMeanPool"],
        "_ChanMaxPool": globals()["_ChanMaxPool"],
        "MCDropout": globals()["MCDropout"],
    }

    try:
        return tf.keras.models.load_model(
            path,
            compile=False,
            safe_mode=False,
            custom_objects=custom_objects,
        )
    except (TypeError, NotImplementedError, ValueError):
        try:
            tf.keras.config.enable_unsafe_deserialization()
            return tf.keras.models.load_model(
                path,
                compile=False,
                custom_objects=custom_objects,
            )
        except (TypeError, NotImplementedError, ValueError):
            # Fallback for notebooks where model already exists in memory.
            for model_name in ("best_visual_model", "visual_model"):
                m = globals().get(model_name)
                if isinstance(m, tf.keras.Model):
                    print(f"Warning: using in-memory '{model_name}' because VISUAL_PATH could not be deserialized.")
                    return m
            raise RuntimeError("Could not load VISUAL_PATH and no in-memory visual model fallback is available.")


def _inverse_hb_predictions(hb_output):
    """Convert normalized hb_output to g/dL, with fallback if _hb_scaler is unavailable."""
    hb_n = np.asarray(hb_output).reshape(-1, 1).astype("float32")

    scaler = globals().get("_hb_scaler")
    if scaler is not None and hasattr(scaler, "inverse_transform"):
        return scaler.inverse_transform(hb_n).ravel()

    if "HB_STD" in globals() and "HB_MEAN" in globals():
        return (hb_n.ravel() * float(HB_STD) + float(HB_MEAN)).astype("float32")

    print("Warning: _hb_scaler and HB_MEAN/HB_STD are missing; using raw hb_output values.")
    return hb_n.ravel()


def _extract_anemia_probability(cls_output):
    """Extract P(Anemic) robustly from either sigmoid (N,1) or 2-class (N,2) output."""
    cls_out = np.asarray(cls_output)

    if cls_out.ndim == 1:
        return cls_out.astype("float32")
    if cls_out.ndim == 2 and cls_out.shape[1] == 1:
        return cls_out[:, 0].astype("float32")
    if cls_out.ndim == 2 and cls_out.shape[1] == 2:
        # Support either probabilities or logits.
        if np.any(cls_out < 0.0) or np.any(cls_out > 1.0):
            cls_out = tf.nn.softmax(cls_out, axis=-1).numpy()
        return cls_out[:, 1].astype("float32")

    raise ValueError(f"Unexpected cls_output shape: {cls_out.shape}")


print("Stage 3: Building Tabular Classifier (Random Forest) ...")
print("  Loading Stage 1 Vision Backbone ...")
_vis_model_rf = _load_visual_backbone(VISUAL_PATH)


def get_stage2_features(model, img_paths, age_arr, gender_f_arr, site_arr):
    """
    Stage 2 - Feature Fusion:
    Run Vision Backbone on images -> concatenate with patient metadata.
    Returns (N, 5) matrix: [hb_est, P(Anemic), Age, Gender_F, Site_ID].
    """
    imgs = _preload_images(img_paths)
    imgs_pre = preprocess_input(imgs)
    out = model.predict(imgs_pre, batch_size=BATCH_SIZE, verbose=0)
    hb_ests = _inverse_hb_predictions(out["hb_output"])
    p_anemic = _extract_anemia_probability(out["cls_output"])
    return np.column_stack([
        hb_ests,      # Stage 1: Hb estimate (g/dL)
        p_anemic,     # Stage 1: P(Anemic)
        age_arr,      # Stage 2: Age(Months)
        gender_f_arr, # Stage 2: Gender_F
        site_arr,     # Stage 2: Site_ID
    ]).astype("float32")


age_all = df_clean["Age(Months)"].to_numpy(dtype="float32")
genderf_all = df_clean["Gender_F"].to_numpy(dtype="float32")

print("  Fusing features - train ...")
Xvis_tr = get_stage2_features(_vis_model_rf, p_tr, age_all[idx_tr], genderf_all[idx_tr], site_tr)
print("  Fusing features - val ...")
Xvis_vl = get_stage2_features(_vis_model_rf, p_vl, age_all[idx_vl], genderf_all[idx_vl], site_vl)
print("  Fusing features - test ...")
Xvis_te = get_stage2_features(_vis_model_rf, p_te, age_all[idx_te], genderf_all[idx_te], site_te)

scaler_vis = StandardScaler().fit(Xvis_tr)
Xvis_tr_s = scaler_vis.transform(Xvis_tr)
Xvis_vl_s = scaler_vis.transform(Xvis_vl)
Xvis_te_s = scaler_vis.transform(Xvis_te)

print("\nTraining Random Forest on [hb_est, P(Anemic), Age, Gender_F, Site_ID] ...")
rf_vis = tune_rf(Xvis_tr_s, y_tr, "RF-Severity [hb_est, P(Anemic), age, gender, site]")
eval_rf(rf_vis, Xvis_tr_s, Xvis_vl_s, Xvis_te_s, y_tr, y_vl, y_te)

# Save model + scaler + site encoder together
joblib.dump({"model": rf_vis, "scaler": scaler_vis, "site_enc": _site_enc}, RF_VIS_PKL)
print(f"\n  Saved -> {RF_VIS_PKL}")

print("\nTest Classification Report (Sequential Hybrid Pipeline):")
pred_vis_te = rf_vis.predict(Xvis_te_s)
print(classification_report(y_te, pred_vis_te, target_names=CLASS_NAMES, zero_division=0))
# Out:
# Stage 3: Building Tabular Classifier (Random Forest) ...
#   Loading Stage 1 Vision Backbone ...
#   Fusing features - train ...
#   Preloading … 2459/2459
#   Fusing features - val ...
#   Preloading … 531/531
#   Fusing features - test ...
#   Preloading … 534/534
#
# Training Random Forest on [hb_est, P(Anemic), Age, Gender_F, Site_ID] ...
# Hyperparameter search — RF-Severity [hb_est, P(Anemic), age, gender, site] ...
#   Best F1 macro (CV): 0.5796
#   Best params: {'max_depth': 10, 'n_estimators': 300}
#   Train — Acc: 0.9089  F1 macro: 0.8916
#   Val   — Acc: 0.4444  F1 macro: 0.3578
#   Test  — Acc: 0.4944  F1 macro: 0.4107
#
#   Saved -> G:\My Drive\Capstone\Bari\Notebook\models\rf_visual_pipeline.pkl
#
# Test Classification Report (Sequential Hybrid Pipeline):
#               precision    recall  f1-score   support
#
#       Normal       0.70      0.59      0.64       225
#         Mild       0.40      0.42      0.41       115
# ...

# %% [markdown]
# ### 5.3 · Multimodal Fusion Architecture
#
# MobileNetV3Small image branch (224×224) concatenated with a dense tabular branch (16 LAB + demographic features). Dual output: `cls_output` (3-class softmax) and `hb_output` (linear regression).
#
# | loss_weights | Phase 1 LR | Phase 2 LR | Backbone unfrozen |
# |-------------|-----------|-----------|------------------|
# | cls: 1.0 · hb: 0.5 | 1e-4 | 2e-5 | Top 40% |

# %%
def build_fusion_model(tab_dim, n_sites, n_bands, model_name="fusion_model"):
    """
    Multimodal fusion: MobileNetV3Small + CBAM (image) + tabular/site/band branches.

    Outputs
    -------
    cls_output : Dense(2, sigmoid) — CORAL ordinal outputs for 3-class severity
                 [P(rank≥1), P(rank≥2)] → decoded by coral_predict()
    hb_output  : Dense(1, linear) — z-score normalised Hb
    """
    # ── Image branch: MobileNetV3Small + CBAM ────────────────────────────────
    img_in     = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name="image_input")
    base_img   = MobileNetV3Small(input_shape=(IMG_SIZE, IMG_SIZE, 3),
                                   include_top=False, weights="imagenet")
    for layer in base_img.layers:
        layer.trainable = False

    feat_map   = base_img(img_in)               # (B, 7, 7, 576)
    feat_map   = cbam_block(feat_map)            # ← channel + spatial attention
    x          = layers.GlobalAveragePooling2D()(feat_map)
    x          = layers.BatchNormalization()(x)
    x          = layers.Dense(128, activation="relu", kernel_regularizer=l2(1e-4))(x)
    x          = layers.Dropout(0.4)(x)

    # ── Tabular branch (LAB/histogram/demo features) ──────────────────────────
    tab_in     = layers.Input(shape=(tab_dim,), name="tab_input")
    t          = layers.Dense(64,  activation="relu", kernel_regularizer=l2(1e-4))(tab_in)
    t          = layers.BatchNormalization()(t)
    t          = layers.Dropout(0.3)(t)
    t          = layers.Dense(32,  activation="relu", kernel_regularizer=l2(1e-4))(t)
    t          = layers.Dropout(0.2)(t)

    # ── Site + age-band embeddings ────────────────────────────────────────────
    site_in    = layers.Input(shape=(1,), name="site_input")
    site_emb   = layers.Embedding(n_sites, 8, name="site_emb")(site_in)
    site_emb   = layers.Flatten()(site_emb)

    band_in    = layers.Input(shape=(1,), name="band_input")
    band_emb   = layers.Embedding(n_bands, 4, name="band_emb")(band_in)
    band_emb   = layers.Flatten()(band_emb)

    clinical   = layers.Concatenate()([t, site_emb, band_emb])  # 32+8+4=44

    # ── Slow Fusion: inject clinical at two levels ────────────────────────────
    fused      = layers.Concatenate()([x, clinical])
    fused      = layers.Dense(256, activation="relu", kernel_regularizer=l2(1e-4))(fused)
    fused      = layers.Dropout(0.4)(fused)
    fused      = layers.Concatenate()([fused, clinical])
    fused      = layers.Dense(128, activation="relu", kernel_regularizer=l2(1e-4))(fused)
    fused      = layers.Dropout(0.3)(fused)

    # ── Outputs ───────────────────────────────────────────────────────────────
    # CORAL: Dense(K-1, sigmoid) = Dense(2, sigmoid) for 3-class ordinal
    cls_out    = layers.Dense(ORDINAL_CLASSES - 1, activation="sigmoid",
                              name="cls_output")(fused)
    hb_out     = layers.Dense(1, activation="linear", name="hb_output")(fused)

    model = models.Model(
        inputs=[img_in, tab_in, site_in, band_in],
        outputs={"cls_output": cls_out, "hb_output": hb_out},
        name=model_name,
    )

    model.compile(
        optimizer=Adam(1e-4),
        loss={
            "cls_output": coral_loss,
            "hb_output" : tf.keras.losses.Huber(delta=1.0),
        },
        loss_weights={"cls_output": 2.0, "hb_output": 0.3},
        metrics={"hb_output": "mae"},
    )
    return model, base_img


mm_model, base_mm = build_fusion_model(
    tab_dim=Xnh_tr.shape[1],
    n_sites=NUM_SITES,
    n_bands=NUM_BANDS,
)
print(f"Fusion model params : {mm_model.count_params():,}")
print(f"cls_output shape    : (B, {ORDINAL_CLASSES - 1}) — CORAL sigmoid")
print(f"hb_output shape     : (B, 1) — Hb z-score")
# Out:
# Fusion model params : 1,145,962
# cls_output shape    : (B, 2) — CORAL sigmoid
# hb_output shape     : (B, 1) — Hb z-score

# %% [markdown]
# ### 5.4 · Training Functions
#
# - **`train_fusion`** — Phase 1: frozen backbone, `patience=20`, monitors `val_loss`
# - **`fine_tune_fusion`** — Phase 2: unfreezes top 40% of backbone at `lr=2e-5`, up to 50 additional epochs

# %%
def train_fusion(model, tr_ds, vl_ds, save_path, name):
    """Phase 1: frozen backbone, LR=1e-4, CORAL loss.
    Monitors val_loss (CORAL is the only classification signal here).
    """
    print(f"\nTraining {name} — Phase 1 (frozen backbone, LR=1e-4) …")
    history = model.fit(
        tr_ds, validation_data=vl_ds,
        epochs=EPOCHS,
        callbacks=[
            ModelCheckpoint(save_path, save_best_only=True,
                            monitor="val_loss", mode="min", verbose=1),
            EarlyStopping(patience=25, restore_best_weights=True,
                          monitor="val_loss", mode="min"),
            ReduceLROnPlateau(monitor="val_loss", factor=0.5,
                              patience=8, min_lr=1e-7, mode="min", verbose=1),
        ],
        verbose=1,
    )
    print(f"  Saved → {save_path}")
    return history


def fine_tune_fusion(model, base, tr_ds, vl_ds, save_path, name, unfreeze_pct=0.4):
    """Phase 2: unfreeze top fraction of backbone.
    LR=1e-5, coral_loss for cls, Huber for Hb.
    """
    n_layers      = len(base.layers)
    unfreeze_from = int(n_layers * (1 - unfreeze_pct))
    for i, layer in enumerate(base.layers):
        if not isinstance(layer, tf.keras.layers.BatchNormalization):
            layer.trainable = i >= unfreeze_from
    n_trainable = sum(1 for l in base.layers if l.trainable)
    print(f"\nFine-tuning {name} — Phase 2 (top {n_trainable}/{n_layers} layers, LR=1e-5) …")

    model.compile(
        optimizer=Adam(1e-5),
        loss={
            "cls_output": coral_loss,
            "hb_output":  tf.keras.losses.Huber(delta=1.0),
        },
        loss_weights={"cls_output": 2.0, "hb_output": 0.5},
        metrics={"hb_output": "mae"},
    )
    history_ft = model.fit(
        tr_ds, validation_data=vl_ds,
        epochs=50,
        callbacks=[
            ModelCheckpoint(save_path, save_best_only=True,
                            monitor="val_loss", mode="min", verbose=1),
            EarlyStopping(patience=15, restore_best_weights=True,
                          monitor="val_loss", mode="min"),
            ReduceLROnPlateau(monitor="val_loss", factor=0.5,
                              patience=5, min_lr=1e-8, mode="min", verbose=1),
        ],
        verbose=1,
    )
    print(f"  Fine-tuned model saved → {save_path}")
    return history_ft

# %% [markdown]
# ### 5.5 · Training Execution
#
# Phase 1 (frozen backbone) followed by Phase 2 (progressive unfreeze). Best checkpoint saved to `MM_B_PATH` based on `val_cls_output_accuracy`.

# %%
# -- Phase 1: frozen backbone --------------------------------------------------
hist_mm = train_fusion(
    mm_model, ds_mm_tr, ds_mm_vl, MM_B_PATH,
    "Fusion (4-class balanced)",
)

# -- Phase 2: unfreeze top 40% of backbone at lower LR -------------------------
# Backward-compatible base backbone resolver (some cells use base_mm, others mm_base).
mm_backbone = globals().get("mm_base", globals().get("base_mm"))
if mm_backbone is None:
    raise NameError("Fusion backbone not found. Run Cell 49 first to build 'mm_model, base_mm'.")

hist_mm_ft = fine_tune_fusion(
    mm_model, mm_backbone, ds_mm_tr, ds_mm_vl, MM_B_PATH,
    "Fusion (4-class balanced)",
    unfreeze_pct=0.4,
)
# Out:
# Training Fusion (4-class balanced) — Phase 1 (frozen backbone, LR=1e-4) …
# Epoch 1/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - cls_output_loss: 0.5562 - hb_output_loss: 0.5935 - hb_output_mae: 0.7179 - loss: 1.3684
# Epoch 1: val_loss improved from None to 1.24415, saving model to G:\My Drive\Capstone\Bari\Notebook\models\multimodal_no_hb.keras
#
# Epoch 1: finished saving model to G:\My Drive\Capstone\Bari\Notebook\models\multimodal_no_hb.keras
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - cls_output_loss: 0.5464 - hb_output_loss: 0.5930 - hb_output_mae: 0.7149 - loss: 1.3495 - val_cls_output_loss: 0.5373 - val_hb_output_loss: 0.3428 - val_hb_output_mae: 0.6823 - val_loss: 1.2441 - learning_rate: 1.2500e-05
# Epoch 2/100
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - cls_output_loss: 0.5686 - hb_output_loss: 0.6350 - hb_output_mae: 0.7449 - loss: 1.4056
# ...

# %% [markdown]
# ### 5.6 · Fusion Model Evaluation
#
# Load the best saved checkpoint and evaluate on the held-out test set. Reports 3-class severity accuracy, macro F1, and Hb regression metrics.

# %%
from sklearn.metrics import precision_score, recall_score

print("Loading fusion model …")
mm_model_ld = tf.keras.models.load_model(
    MM_B_PATH, compile=False,
    custom_objects={"coral_loss": coral_loss},
)
print(f"Hb normalisation — mean: {HB_MEAN:.2f}  std: {HB_STD:.2f}")

ds_mm_te = make_fusion_ds(p_te, Xnh_te, site_te, band_te, y3_te, hb_te_n,
                           augment=False, shuffle=False)

out    = mm_model_ld.predict(ds_mm_te, verbose=0)
coral_sig = out["cls_output"]                                   # (N, 2) sigmoids
preds     = coral_predict(coral_sig).numpy()                    # (N,) int class
hb_n      = out["hb_output"].squeeze()

acc_imp  = accuracy_score(y3_te, preds)
f1_imp   = f1_score(y3_te, preds, average="macro", zero_division=0)
prec_imp = precision_score(y3_te, preds, average="macro", zero_division=0)
rec_imp  = recall_score(y3_te, preds, average="macro", zero_division=0)

hb_pred = hb_n * HB_STD + HB_MEAN
hb_true = hb_te_n * HB_STD + HB_MEAN
mae_imp  = np.mean(np.abs(hb_pred - hb_true))
rmse_imp = np.sqrt(np.mean((hb_pred - hb_true) ** 2))
r2_imp   = 1 - np.sum((hb_true - hb_pred)**2) / (np.sum((hb_true - hb_true.mean())**2) + 1e-8)

print("\n" + "="*55)
print("Fusion (CORAL 3-class: No Anemia | Mild-Moderate | Severe)")
print("="*55)
print(f"  [Severity]  Acc={acc_imp:.4f}  F1={f1_imp:.4f}  Prec={prec_imp:.4f}  Rec={rec_imp:.4f}")
print(f"  [Hb Regr.]  MAE={mae_imp:.3f} g/dL  RMSE={rmse_imp:.3f}  R²={r2_imp:.4f}")

# Severe anemia sensitivity
severe_mask = (y3_te == 2)
if severe_mask.sum() > 0:
    sev_sens = (preds[severe_mask] == 2).sum() / severe_mask.sum()
    print(f"  [Severe]    Sensitivity={sev_sens:.3f}  (n={severe_mask.sum()})")

print(classification_report(y3_te, preds,
                             labels=list(range(ORDINAL_CLASSES)),
                             target_names=ORDINAL_NAMES, zero_division=0))

cm = confusion_matrix(y3_te, preds)
plt.figure(figsize=(6, 5))
sns.heatmap(cm / cm.sum(axis=1, keepdims=True), annot=True, fmt=".2f",
            cmap="Blues", xticklabels=ORDINAL_NAMES, yticklabels=ORDINAL_NAMES)
plt.title("Fusion CORAL — 3-class Ordinal Severity\nNormalised Confusion Matrix",
          fontweight="bold")
plt.ylabel("True"); plt.xlabel("Predicted")
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "cm_fusion_coral.png"), dpi=150)
plt.show()
# Out:
# Loading fusion model …
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\saving\serialization_lib.py:733, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     732 try:
# --> 733     instance = cls.from_config(inner_config)
#     734 except TypeError as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\models\model.py:823, in Model.from_config(cls, config, custom_objects)
#     821     from keras.src.models.functional import functional_from_config
# --> 823     return functional_from_config(
#     824         cls, config, custom_objects=custom_objects
#     825     )
# ...

# %% [markdown]
# ---
# ## 5 · Baseline Comparison: Tabular Models
#
# Tabular models trained on handcrafted LAB colour features as a reference baseline. The **RF With HB** variant serves as an oracle upper-bound showing the performance ceiling when real Hb values are available.
#
# | Model | Features | Purpose |
# |-------|----------|---------|
# | **RF With HB** | LAB + Hb + Age + Gender (17 features) | Oracle upper-bound — requires blood test |
# | **RF Without HB** | LAB + Age + Gender (16 features) | Non-invasive colour-only baseline |
# | **Logistic Regression** | LAB + Age + Gender (16 features) | Linear comparison |
# | **XGBoost** | LAB + Age + Gender (16 features) | Gradient boosting comparison |
# | **MLP** | LAB + Age + Gender (16 features) | Neural network comparison |

# %% [markdown]
# ### 5.1 · Class Imbalance & Weights
#
# Compute balanced class weights for the 4-class severity distribution before training.

# %%
classes       = np.unique(y_tr)
cw_values     = compute_class_weight(class_weight="balanced", classes=classes, y=y_tr)
class_weights = dict(zip(classes, cw_values))

print("Class weights (balanced):")
for idx, w in class_weights.items():
    print(f"  {CLASS_NAMES[idx]:15s} ({idx}): {w:.4f}")
# Out:
# Class weights (balanced):
#   Normal          (0): 0.5783
#   Mild            (1): 1.2246
#   Moderate        (2): 0.8610
#   Severe          (3): 3.4153

# %% [markdown]
# ### 5.2 · Random Forest Training
#
# `GridSearchCV` — exhaustive search over `n_estimators` × `max_depth`, `StratifiedKFold(5)`, scoring: `f1_macro`.

# %%
print("Tabular A — WITH HB_LEVEL  (oracle / upper-bound)")
model_tab_wh = tune_rf(Xwh_tr, y_tr, "RF With HB")
eval_rf(model_tab_wh, Xwh_tr, Xwh_vl, Xwh_te, y_tr, y_vl, y_te)

pred_wh_te  = model_tab_wh.predict(Xwh_te)
pred_wh_val = model_tab_wh.predict(Xwh_vl)
pred_wh_tr  = model_tab_wh.predict(Xwh_tr)

print(f"\nTest Classification Report (With HB):")
print(classification_report(y_te, pred_wh_te, target_names=CLASS_NAMES, zero_division=0))
# Out:
# Tabular A — WITH HB_LEVEL  (oracle / upper-bound)
# Hyperparameter search — RF With HB ...
#   Best F1 macro (CV): 0.9783
#   Best params: {'max_depth': 15, 'n_estimators': 500}
#   Train — Acc: 1.0000  F1 macro: 1.0000
#   Val   — Acc: 0.9435  F1 macro: 0.9210
#   Test  — Acc: 0.9757  F1 macro: 0.9765
#
# Test Classification Report (With HB):
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      0.99       225
#         Mild       0.93      0.96      0.94       115
#     Moderate       0.97      0.97      0.97       159
#       Severe       1.00      1.00      1.00        35
#
#     accuracy                           0.98       534
#    macro avg       0.98      0.98      0.98       534
# weighted avg       0.98      0.98      0.98       534

# %%
# Feature importance — RF With HB
imp  = model_tab_wh.feature_importances_
cols = [f.replace("(Months)", "").strip() for f in FEAT_WITH_HB]
colors = ["#e74c3c" if "HB" in f else
          "#e67e22" if "a_mean" in f else "#3498db" for f in FEAT_WITH_HB]

fig, ax = plt.subplots(figsize=(8, 6))
bars = ax.barh(cols, imp, color=colors)
ax.set_xlabel("Importance")
ax.set_title("Feature Importance — RF With HB (oracle)", fontweight="bold")
ax.bar_label(bars, fmt="%.3f", padding=3)
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "feature_importance.png"), bbox_inches="tight", dpi=120)
plt.show()

# %% [markdown]
# ### 5.3 · Additional Classifiers
#
# Logistic Regression, XGBoost, and MLP trained on the same no-HB feature set (`FEAT_NO_HB`) for a broader baseline comparison.

# %%
from sklearn.linear_model import LogisticRegression

print("Logistic Regression — with HB")
lr_wh = LogisticRegression(max_iter=2000, C=1.0, class_weight="balanced",
                            random_state=SEED, solver="lbfgs")
lr_wh.fit(Xwh_tr, y_tr)
lr_wh_pred = lr_wh.predict(Xwh_te)
print(f"  Test Acc: {accuracy_score(y_te, lr_wh_pred):.4f}  "
      f"F1: {f1_score(y_te, lr_wh_pred, average='macro'):.4f}")
# Out:
# Logistic Regression — with HB
#   Test Acc: 0.9382  F1: 0.9242

# %%
try:
    from xgboost import XGBClassifier
    _HAS_XGB = True
except ImportError:
    _HAS_XGB = False
    print("XGBoost not installed — skipping. Run: pip install xgboost")

if _HAS_XGB:
    xgb_params = dict(
        n_estimators=300, max_depth=6, learning_rate=0.05,
        use_label_encoder=False, eval_metric="mlogloss",
        random_state=SEED, n_jobs=-1,
    )
    print("XGBoost — with HB")
    xgb_wh = XGBClassifier(**xgb_params)
    xgb_wh.fit(Xwh_tr, y_tr, eval_set=[(Xwh_vl, y_vl)], verbose=False)
    xgb_wh_pred = xgb_wh.predict(Xwh_te)
    print(f"  Test Acc: {accuracy_score(y_te, xgb_wh_pred):.4f}  "
          f"F1: {f1_score(y_te, xgb_wh_pred, average='macro'):.4f}")
else:
    xgb_wh_pred = np.zeros_like(y_te)
# Out:
# XGBoost — with HB
#   Test Acc: 1.0000  F1: 1.0000

# %%
from sklearn.neural_network import MLPClassifier

mlp_params = dict(
    hidden_layer_sizes=(128, 64, 32),
    activation="relu",
    max_iter=500,
    early_stopping=True,
    validation_fraction=0.15,
    random_state=SEED,
)

print("MLP Neural Network — with HB")
mlp_wh = MLPClassifier(**mlp_params)
mlp_wh.fit(Xwh_tr, y_tr)
mlp_wh_pred = mlp_wh.predict(Xwh_te)
print(f"  Test Acc: {accuracy_score(y_te, mlp_wh_pred):.4f}  "
      f"F1: {f1_score(y_te, mlp_wh_pred, average='macro'):.4f}")
# Out:
# MLP Neural Network — with HB
#   Test Acc: 0.9232  F1: 0.8939

# %%
rows = [
    ("Random Forest",       "With HB", pred_wh_te),
    ("Logistic Regression", "With HB", lr_wh_pred),
    ("MLP",                 "With HB", mlp_wh_pred),
]
if _HAS_XGB:
    rows += [("XGBoost", "With HB", xgb_wh_pred)]

records = [
    {
        "Model":    name,
        "Setup":    setup,
        "Accuracy": round(accuracy_score(y_te, preds), 4),
        "F1 Macro": round(f1_score(y_te, preds, average="macro", zero_division=0), 4),
    }
    for name, setup, preds in rows
]

df_tab_results = pd.DataFrame(records).sort_values("F1 Macro", ascending=False).reset_index(drop=True)
display(df_tab_results)
# Out:
#                  Model    Setup  Accuracy  F1 Macro
# 0              XGBoost  With HB    1.0000    1.0000
# 1        Random Forest  With HB    0.9757    0.9765
# 2  Logistic Regression  With HB    0.9382    0.9242
# 3                  MLP  With HB    0.9232    0.8939

# %% [markdown]
# ---
# ## 6 · Explainability
#
# ### 6.1 · SHAP Analysis (Random Forest)
#
# `TreeExplainer` on the RF models — summary plot, dependence plot, and feature importance bar chart. Shows which LAB colour features most influence severity prediction and how they interact with Hb level.

# %%
# ── SHAP — Tabular A (with HB_LEVEL) ─────────────────────────────────────────
print("Computing SHAP values for Tabular A (with HB) …")
explainer_a   = shap.TreeExplainer(model_tab_wh)
shap_values_a = explainer_a.shap_values(Xwh_vl)

# Normalise to list format regardless of SHAP version
if isinstance(shap_values_a, np.ndarray) and shap_values_a.ndim == 3:
    shap_list_a = [shap_values_a[:, :, c] for c in range(shap_values_a.shape[2])]
else:
    shap_list_a = shap_values_a if isinstance(shap_values_a, list) else [shap_values_a]

feat_labels_wh = [f.replace("(Months)", "").strip() for f in FEAT_WITH_HB]

# Global summary plot (mean |SHAP| across all classes)
shap_abs_mean_a = np.mean([np.abs(sv) for sv in shap_list_a], axis=0)
plt.figure(figsize=(8, 5))
shap.summary_plot(shap_abs_mean_a, Xwh_vl, feature_names=feat_labels_wh,
                  plot_type="bar", show=False)
plt.title("SHAP Feature Importance — Tabular A (With HB)", fontweight="bold")
plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "shap_tabular_A.png"), bbox_inches="tight", dpi=120)
plt.show()
print("Tabular A SHAP done.")
# Out:
# Computing SHAP values for Tabular A (with HB) …
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # ── SHAP — Tabular A (with HB_LEVEL) ─────────────────────────────────────────
#       2 print("Computing SHAP values for Tabular A (with HB) …")
# ----> 3 explainer_a   = shap.TreeExplainer(model_tab_wh)
#       4 shap_values_a = explainer_a.shap_values(Xwh_vl)
#       6 # Normalise to list format regardless of SHAP version
#
# NameError: name 'shap' is not defined

# %%
interp_map = {
    "RF With HB (oracle)":  "LAB + real HB + Age + Gender — requires blood test (upper bound)",
    "Visual CNN (binary)":  "Image only — binary Anemic / Non-Anemic + Hb estimate",
    "Visual → RF Severity": "Image → estimated Hb → RF severity classifier (non-invasive pipeline)",
    "Fusion CORAL (3-class)": "Image + LAB + Age + Gender → WHO severity + Hb estimate (ordinal)",
}

rows = [res_tab_a, res_vis, res_tab_pipeline, res_mm]
results_df = pd.DataFrame([{
    "Model":    r["Model"],
    "Setup":    interp_map.get(r["Model"], ""),
    "Accuracy": f"{r['acc']:.4f}",
    "Macro-F1": f"{r['f1']:.4f}",
    "Hb MAE":   f"{r['hb_mae']:.3f}" if r.get("hb_mae") else "—",
} for r in rows if r is not None]).reset_index(drop=True)

display(results_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 8
#       1 interp_map = {
#       2     "RF With HB (oracle)":  "LAB + real HB + Age + Gender — requires blood test (upper bound)",
#       3     "Visual CNN (binary)":  "Image only — binary Anemic / Non-Anemic + Hb estimate",
#       4     "Visual → RF Severity": "Image → estimated Hb → RF severity classifier (non-invasive pipeline)",
#       5     "Fusion CORAL (3-class)": "Image + LAB + Age + Gender → WHO severity + Hb estimate (ordinal)",
#       6 }
# ----> 8 rows = [res_tab_a, res_vis, res_tab_pipeline, res_mm]
#       9 results_df = pd.DataFrame([{
#      10     "Model":    r["Model"],
#      11     "Setup":    interp_map.get(r["Model"], ""),
#    (...)     14     "Hb MAE":   f"{r['hb_mae']:.3f}" if r.get("hb_mae") else "—",
#      15 } for r in rows if r is not None]).reset_index(drop=True)
# ...

# %% [markdown]
# ---
# ## 7 · Full Evaluation & Results
#
# Evaluate all trained models on the held-out test set and summarise performance side-by-side.
#
# | Model | Setup | Metric focus |
# |-------|-------|-------------|
# | RF With HB (oracle) | LAB + real Hb + demographics | Upper-bound reference |
# | Visual CNN | Image only | Binary Acc · F1 · Hb MAE |
# | RF Severity Pipeline | Visual outputs → RF | 4-class F1 macro |
# | Multimodal Fusion | Image + LAB + demographics | 3-class F1 macro · Hb R² |

# %%
from sklearn.metrics import precision_score, recall_score, roc_auc_score, roc_curve


def eval_keras_binary(model, ds, y_true, name):
    """Evaluate a sigmoid(1) binary model; reports AUROC + sensitivity."""
    out   = model.predict(ds, verbose=0)
    probs = out["cls_output"].flatten()   # (N,) sigmoid scores
    hb_n  = out["hb_output"].flatten()
    preds = (probs >= 0.5).astype(int)
    acc   = accuracy_score(y_true, preds)
    f1    = f1_score(y_true, preds, average="macro", zero_division=0)
    prec  = precision_score(y_true, preds, average="macro", zero_division=0)
    rec   = recall_score(y_true, preds, average="macro", zero_division=0)
    try:
        auroc = roc_auc_score(y_true, probs)
        fpr, tpr, _ = roc_curve(y_true, probs)
        sens90 = tpr[np.argmin(np.abs(fpr - 0.10))]
    except ValueError:
        auroc = sens90 = float("nan")
    print(f"\n{'=' * 55}\n  {name}")
    print(f"  Accuracy  : {acc:.4f}  |  Macro-F1 : {f1:.4f}")
    print(f"  AUROC     : {auroc:.4f}  |  Sens@90%Spec : {sens90:.3f}")
    print(classification_report(y_true, preds,
                                target_names=VISUAL_CLASS_NAMES, zero_division=0))
    cm = confusion_matrix(y_true, preds)
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm / cm.sum(axis=1, keepdims=True), annot=True, fmt=".2f",
                cmap="Blues", xticklabels=VISUAL_CLASS_NAMES, yticklabels=VISUAL_CLASS_NAMES)
    plt.title(f"{name}\nNormalised Confusion Matrix", fontweight="bold")
    plt.ylabel("True"); plt.xlabel("Predicted")
    plt.tight_layout()
    fname = name.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_")
    plt.savefig(os.path.join(RESULTS_DIR, f"cm_{fname}.png"), dpi=150)
    plt.show()
    return {"Model": name, "acc": acc, "f1": f1, "prec": prec, "rec": rec,
            "auroc": auroc, "sens90spec": sens90, "preds": preds, "hb_n": hb_n}


def eval_fusion(model, ds, y_true, hb_true_n, name):
    """Evaluate fusion model with CORAL decode + Hb regression + clinical metrics."""
    out       = model.predict(ds, verbose=0)
    coral_sig = out["cls_output"]                    # (N, 2)
    hb_n      = out["hb_output"].squeeze()
    preds     = coral_predict(coral_sig).numpy()     # (N,) ordinal class
    acc   = accuracy_score(y_true, preds)
    f1    = f1_score(y_true, preds, average="macro", zero_division=0)
    prec  = precision_score(y_true, preds, average="macro", zero_division=0)
    rec   = recall_score(y_true, preds, average="macro", zero_division=0)
    hb_pred = hb_n * HB_STD + HB_MEAN
    hb_true = hb_true_n * HB_STD + HB_MEAN
    mae  = np.mean(np.abs(hb_pred - hb_true))
    rmse = np.sqrt(np.mean((hb_pred - hb_true) ** 2))
    r2   = 1 - np.sum((hb_true - hb_pred) ** 2) / (np.sum((hb_true - hb_true.mean()) ** 2) + 1e-8)
    # Severe anemia sensitivity
    sev_mask = (y_true == 2)
    sev_sens = (preds[sev_mask] == 2).sum() / sev_mask.sum() if sev_mask.sum() > 0 else float("nan")
    print(f"\n{'=' * 55}\n  {name}")
    print(f"  [Severity]  Acc={acc:.4f}  F1={f1:.4f}  Prec={prec:.4f}  Rec={rec:.4f}")
    print(f"  [Hb Regr.]  MAE={mae:.3f} g/dL  RMSE={rmse:.3f}  R²={r2:.4f}")
    print(f"  [Severe]    Sensitivity={sev_sens:.3f}  (n={sev_mask.sum()})")
    print(classification_report(y_true, preds,
                                labels=list(range(ORDINAL_CLASSES)),
                                target_names=ORDINAL_NAMES, zero_division=0))
    cm = confusion_matrix(y_true, preds)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm / cm.sum(axis=1, keepdims=True), annot=True, fmt=".2f",
                cmap="Blues", xticklabels=ORDINAL_NAMES, yticklabels=ORDINAL_NAMES)
    plt.title(f"{name}\nNormalised Confusion Matrix", fontweight="bold")
    plt.ylabel("True"); plt.xlabel("Predicted")
    plt.tight_layout()
    fname = name.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_")
    plt.savefig(os.path.join(RESULTS_DIR, f"cm_{fname}.png"), dpi=150)
    plt.show()
    return {"Model": name, "acc": acc, "f1": f1, "prec": prec, "rec": rec,
            "hb_mae": mae, "hb_rmse": rmse, "hb_r2": r2,
            "severe_sens": sev_sens, "preds": preds}


def eval_sklearn(y_true, preds, name, class_names=None):
    if class_names is None:
        class_names = CLASS_NAMES
    acc  = accuracy_score(y_true, preds)
    f1   = f1_score(y_true, preds, average="macro", zero_division=0)
    prec = precision_score(y_true, preds, average="macro", zero_division=0)
    rec  = recall_score(y_true, preds, average="macro", zero_division=0)
    print(f"\n{'=' * 55}\n  {name}")
    print(f"  Accuracy  : {acc:.4f}  |  Macro-F1 : {f1:.4f}")
    print(f"  Precision : {prec:.4f}  |  Recall   : {rec:.4f}")
    cm = confusion_matrix(y_true, preds)
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm / cm.sum(axis=1, keepdims=True), annot=True, fmt=".2f",
                cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.title(f"{name}\nNormalised Confusion Matrix", fontweight="bold")
    plt.ylabel("True"); plt.xlabel("Predicted")
    plt.tight_layout()
    fname = name.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_")
    plt.savefig(os.path.join(RESULTS_DIR, f"cm_{fname}.png"), dpi=150)
    plt.show()
    return {"Model": name, "acc": acc, "f1": f1, "prec": prec, "rec": rec, "preds": preds}


visual_model = tf.keras.models.load_model(VISUAL_PATH, compile=False)
mm_model_ld  = tf.keras.models.load_model(
    MM_B_PATH, compile=False,
    custom_objects={"coral_loss": coral_loss},
)

ds_mm_te = make_fusion_ds(p_te, Xnh_te, site_te, band_te, y3_te, hb_te_n,
                           augment=False, shuffle=False)

ages_te_ev    = df_clean["Age(Months)"].to_numpy()[idx_te]
genders_te_ev = df_clean["GENDER"].to_numpy()[idx_te]

# RF With HB oracle (real Hb from CSV — upper bound only)
res_tab_a = eval_sklearn(y_te, pred_wh_te, "RF With HB (oracle)")

# Visual CNN binary evaluation with AUROC
print("\nVisual CNN — TTA ...")
vis_cls_probs, hb_vis_n = predict_tta(visual_model, p_te, y_te_bin, hb_te_n, n_aug=8)
vis_preds = (vis_cls_probs >= 0.5).astype(int)
res_vis   = eval_sklearn(y_te_bin, vis_preds, "Visual CNN (binary)",
                         class_names=VISUAL_CLASS_NAMES)
try:
    vis_auroc = roc_auc_score(y_te_bin, vis_cls_probs)
    fpr_v, tpr_v, _ = roc_curve(y_te_bin, vis_cls_probs)
    sens90_v = tpr_v[np.argmin(np.abs(fpr_v - 0.10))]
    print(f"  AUROC: {vis_auroc:.4f}  |  Sens@90%Spec: {sens90_v:.3f}")
except ValueError:
    pass

# Estimated Hb from visual model (z-score → g/dL)
hb_vis = hb_vis_n * HB_STD + HB_MEAN

# Pipeline: Visual → estimated Hb → RF With HB → severity
_N_COLOUR_HIST = len(_COLOUR_FEATS) + len(_HIST_FEATS)
_HB_IDX_WH    = FEAT_WITH_HB.index("HB_LEVEL")

X_pipe_te = np.empty((len(y_te), len(FEAT_WITH_HB)), dtype=float)
X_pipe_te[:, :_N_COLOUR_HIST] = X_no_hb[idx_te][:, :_N_COLOUR_HIST]
X_pipe_te[:, _HB_IDX_WH]      = hb_vis
X_pipe_te[:, _HB_IDX_WH + 1:] = X_no_hb[idx_te][:, _N_COLOUR_HIST:]
X_pipe_te_s   = scaler_wh.transform(X_pipe_te)
pred_pipeline = model_tab_wh.predict(X_pipe_te_s)
res_tab_pipeline = eval_sklearn(y_te, pred_pipeline, "Visual → RF Severity")

# Fusion CORAL model
res_mm = eval_fusion(mm_model_ld, ds_mm_te, y3_te, hb_te_n, "Fusion CORAL (3-class)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 102
#      98     plt.show()
#      99     return {"Model": name, "acc": acc, "f1": f1, "prec": prec, "rec": rec, "preds": preds}
# --> 102 visual_model = tf.keras.models.load_model(VISUAL_PATH, compile=False)
#     103 mm_model_ld  = tf.keras.models.load_model(
#     104     MM_B_PATH, compile=False,
#     105     custom_objects={"coral_loss": coral_loss},
#     106 )
#     108 ds_mm_te = make_fusion_ds(p_te, Xnh_te, site_te, band_te, y3_te, hb_te_n,
#     109                            augment=False, shuffle=False)
#
# NameError: name 'tf' is not defined

# %%
interp_map = {
    "RF With HB (oracle)":  "LAB + real HB + Age + Gender — requires blood test (upper bound)",
    "Visual CNN (binary)":  "Image only — binary Anemic / Non-Anemic + Hb estimate",
    "Visual → RF Severity": "Image → estimated Hb → RF severity classifier (non-invasive pipeline)",
    "Fusion (dual output)": "Image + LAB + Age + Gender → WHO severity + Hb estimate",
}

rows = [res_tab_a, res_vis, res_tab_pipeline, res_mm]
results_df = pd.DataFrame([{
    "Model":    r["Model"],
    "Setup":    interp_map.get(r["Model"], ""),
    "Accuracy": f"{r['acc']:.4f}",
    "Macro-F1": f"{r['f1']:.4f}",
    "Hb MAE":   f"{r['hb_mae']:.3f}" if r.get("hb_mae") else "—",
} for r in rows if r is not None]).reset_index(drop=True)

display(results_df)

print("\nKey takeaways:")
print("  1. RF With HB is the oracle — it requires a real blood test and sets the ceiling.")
print("  2. Visual CNN estimates Hb; feeding it into RF gives the non-invasive pipeline.")
print("  3. Fusion jointly learns severity + Hb from image + LAB features end-to-end.")
print("  4. Macro-F1 is the primary metric — labels are WHO age/gender-aware thresholds.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 8
#       1 interp_map = {
#       2     "RF With HB (oracle)":  "LAB + real HB + Age + Gender — requires blood test (upper bound)",
#       3     "Visual CNN (binary)":  "Image only — binary Anemic / Non-Anemic + Hb estimate",
#       4     "Visual → RF Severity": "Image → estimated Hb → RF severity classifier (non-invasive pipeline)",
#       5     "Fusion (dual output)": "Image + LAB + Age + Gender → WHO severity + Hb estimate",
#       6 }
# ----> 8 rows = [res_tab_a, res_vis, res_tab_pipeline, res_mm]
#       9 results_df = pd.DataFrame([{
#      10     "Model":    r["Model"],
#      11     "Setup":    interp_map.get(r["Model"], ""),
#    (...)     14     "Hb MAE":   f"{r['hb_mae']:.3f}" if r.get("hb_mae") else "—",
#      15 } for r in rows if r is not None]).reset_index(drop=True)
# ...

# %% [markdown]
# ---
# ## 8 · Inference Pipeline
#
# End-to-end prediction from a single conjunctiva image and patient demographics.
#
# ### 8.1 · Nutritional Recommendation Module
#
# Rule-based system mapping predicted severity to structured dietary advice (JSON output).

# %%
# ── Nutritional guidelines map ────────────────────────────────────────────────
nutrition_map = {
    "Normal": {
        "advice": "Maintain balanced diet with iron-rich foods.",
        "foods":  ["Lean meats", "Dark leafy greens", "Legumes", "Fortified cereals",
                   "Citrus fruits"],
        "referral": "No referral needed. Annual check-up recommended.",
    },
    "Mild": {
        "advice": "Increase iron-rich foods and vitamin C intake to enhance absorption.",
        "foods":  ["Spinach", "Lentils", "Kidney beans", "Bell peppers",
                   "Fortified cereals", "Dried apricots"],
        "referral": "Schedule physician visit within 4 weeks.",
    },
    "Moderate": {
        "advice": ("Structured dietary plan: iron, folate, and B12. "
                   "Medical consultation required."),
        "foods":  ["Liver", "Red meat", "Oysters", "Dark leafy greens",
                   "Iron-fortified foods", "Eggs", "Legumes"],
        "referral": ("Medical consultation within 2 weeks. "
                     "Request CBC + serum ferritin + serum iron."),
    },
    "Severe": {
        "advice": "Immediate clinical attention required. Diet alone is insufficient.",
        "foods":  ["Iron-rich foods as tolerated under medical supervision"],
        "referral": ("URGENT — emergency referral. "
                     "Risk of cardiac complications at HB < 7 g/dL."),
    },
}

print("Nutritional guidelines loaded for:", list(nutrition_map.keys()))
# Out:
# Nutritional guidelines loaded for: ['Normal', 'Mild', 'Moderate', 'Severe']

# %%
def predict_anemia(image_input, age_months: int, gender: str,
                   city: str = "Unknown",
                   use_model: str = "tabular") -> dict:
    """
    End-to-end Sequential Hybrid inference.

    Parameters
    ----------
    image_input : str | np.ndarray   Conjunctiva image path or BGR array.
    age_months  : int                Patient age in months.
    gender      : str                'male' | 'female'.
    city        : str                Screening city/town (e.g. 'Kumasi', 'Bolgatanga').
    use_model   : str                'tabular' (default) | 'visual' | 'fusion'.
    """
    if isinstance(image_input, str):
        bgr_img = load_image(image_input)
    elif isinstance(image_input, np.ndarray):
        bgr_img = cv2.resize(image_input, (IMG_SIZE, IMG_SIZE))
    else:
        raise ValueError("image_input must be a file path or BGR numpy array.")

    if bgr_img is None:
        raise ValueError("Could not load image.")

    gender_f = 1.0 if str(gender).lower().startswith("f") else 0.0

    city_clean  = str(city).strip()
    site_id_int = int(_site_enc.transform([city_clean])[0]) \
                  if city_clean in _site_enc.classes_ else 0
    band_id_int = age_band(age_months)

    rgb_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2RGB).astype(np.float32)
    img_pre = preprocess_input(_apply_clahe_np(rgb_img))
    img_t   = np.expand_dims(img_pre, 0)

    hb_pred  = None
    severity = None

    if use_model == "tabular":
        out_vis  = visual_model.predict(img_t, verbose=0)
        probs_v  = out_vis["cls_output"][0]
        hb_pred  = float(_hb_scaler.inverse_transform(
                       out_vis["hb_output"].reshape(-1, 1))[0, 0])
        binary   = VISUAL_CLASS_NAMES[int(np.argmax(probs_v))]

        fused = np.array([[
            hb_pred, float(probs_v[1]), float(age_months), gender_f, float(site_id_int),
        ]], dtype="float32")
        fused_s  = scaler_vis.transform(fused)
        probs    = rf_vis.predict_proba(fused_s)[0]
        pred_idx = int(np.argmax(probs))
        severity = CLASS_NAMES[pred_idx]

    elif use_model == "visual":
        out      = visual_model.predict(img_t, verbose=0)
        probs    = out["cls_output"][0]
        hb_pred  = float(_hb_scaler.inverse_transform(
                       out["hb_output"].reshape(-1, 1))[0, 0])
        severity = anemia_label(hb_pred, age_months, gender)
        pred_idx = int(np.argmax(probs))
        binary   = VISUAL_CLASS_NAMES[pred_idx]

    elif use_model == "fusion":
        lab_feats  = extract_lab_features(bgr_img)
        tab_raw    = {**lab_feats,
                      "Age(Months)": float(age_months),
                      "Gender_F": gender_f,
                      "age_baseline_hb": who_hb_prior(age_months)}
        tab_vec    = np.array([[tab_raw.get(f, 0.0) for f in FEAT_NO_HB]], dtype="float32")
        tab_sc     = scaler_nh.transform(tab_vec).astype("float32")
        out = mm_model_ld.predict({
            "image_input": img_t,
            "tab_input":   tab_sc,
            "site_input":  np.array([[site_id_int]], dtype="int32"),
            "band_input":  np.array([[band_id_int]], dtype="int32"),
        }, verbose=0)
        probs    = out["cls_output"][0]
        hb_pred  = float(_hb_scaler.inverse_transform(
                       out["hb_output"].reshape(-1, 1))[0, 0])
        severity = anemia_label(hb_pred, age_months, gender)
        pred_idx = int(np.argmax(probs))
        binary   = "Anemic" if pred_idx > 0 else "Non-Anemic"

    else:
        raise ValueError(f"Unknown use_model='{use_model}'. Choose: tabular | visual | fusion")

    return {
        "binary_class":    binary,
        "severity":        severity,
        "hb_estimate_gdl": round(hb_pred, 2),
        "confidence":      round(float(np.max(probs)), 4),
        "probabilities":   {CLASS_NAMES[i]: round(float(p), 4) for i, p in enumerate(probs)}
                           if use_model != "visual" else
                           {VISUAL_CLASS_NAMES[i]: round(float(p), 4) for i, p in enumerate(probs)},
    }

# %% [markdown]
# ### 8.2 · `predict_anemia` — End-to-End Sequential Hybrid Inference
#
# ```python
# result = predict_anemia(image, age_months=18, gender="female",
#                         hospital="Baguio General Hospital", use_model="tabular")
# ```
#
# | `use_model` | Pipeline | Default? |
# |------------|---------|---------|
# | `"tabular"` | Stage 1 CNN → Stage 2 Fusion → Stage 3 RF | ✓ Primary |
# | `"visual"` | CNN only → WHO threshold severity | — |
# | `"fusion"` | CNN + LAB features → Fusion CNN | — |

# %% [markdown]
# ---
# ## 9 · Model Persistence
#
# ### 9.1 · Save All Models
#
# Persist all trained models and scalers to disk for downstream inference and deployment.

# %%
joblib.dump({
    "model":         model_tab_wh,
    "scaler":        scaler_wh,
    "feature_names": FEAT_WITH_HB,
    "hb_scaler":     _hb_scaler,
    
}, TAB_WH_PKL)

# Also save scaler_nh separately (needed by fusion model in API)
joblib.dump({
    "scaler":        scaler_nh,
    "feature_names": FEAT_NO_HB,
}, os.path.join(MODELS_DIR, "scaler_no_hb.pkl"))

print("Saved models:")
for label, path in [
    ("tabular_with_hb.pkl", TAB_WH_PKL),
    ("scaler_no_hb.pkl",    os.path.join(MODELS_DIR, "scaler_no_hb.pkl")),
    ("visual_model.keras",  VISUAL_PATH),
    ("multimodal.keras",    MM_B_PATH),
]:
    size   = os.path.getsize(path) / 1e6 if os.path.exists(path) else 0
    status = f"{size:.1f} MB" if size > 0 else "NOT FOUND"
    print(f"  {label:30s} {status}")
# Out:
# Saved models:
#   tabular_with_hb.pkl            28.0 MB
#   scaler_no_hb.pkl               0.0 MB
#   visual_model.keras             13.1 MB
#   multimodal.keras               12.6 MB

# %% [markdown]
# ### 9.2 · TFLite Quantization & Benchmark
#
# Convert Keras models to **TensorFlow Lite** with post-training dynamic-range quantization. Measures model size reduction and per-inference latency for mobile deployment.

# %%
def to_tflite(keras_path, out_name, quantize=True):
    model        = tf.keras.models.load_model(keras_path, compile=False)
    converter    = tf.lite.TFLiteConverter.from_keras_model(model)
    if quantize:
        converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite_bytes = converter.convert()
    out_path     = os.path.join(TFLITE_DIR, out_name)
    with open(out_path, "wb") as f:
        f.write(tflite_bytes)
    size_mb = os.path.getsize(out_path) / 1024 ** 2
    print(f"  Saved : {out_name}  ({size_mb:.2f} MB)")
    return out_path, size_mb


print("Converting to TFLite (quantized)...\n")
tflite_paths = {}

for label, keras_p, out_n in [
    ("Visual", VISUAL_PATH, "visual_model.tflite"),
    ("Fusion", MM_B_PATH,   "multimodal_model.tflite"),
]:
    print(f"{label}:")
    try:
        path, mb = to_tflite(keras_p, out_n, quantize=True)
        tflite_paths[label] = path
    except Exception as e:
        print(f"  ERROR: {e}")

print(f"\nConverted {len(tflite_paths)}/2 models.")
# Out:
# Converting to TFLite (quantized)...
#
# Visual:
# Saved artifact at 'C:\Users\USER\AppData\Local\Temp\tmpod5_nx3h'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   Dict[['cls_output', TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)], ['hb_output', TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)]]
# Captures:
#   2129327738128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129327750224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129327749264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129327736976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129327745424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129327737936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2129327744080: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...

# %%
# ── Benchmark & validate TFLite ───────────────────────────────────────────────
def bench_tflite(tflite_path, n_runs=50):
    """Measure inference latency and validate output."""
    interp = tf.lite.Interpreter(model_path=tflite_path)
    interp.allocate_tensors()
    in_dets  = interp.get_input_details()
    out_dets = interp.get_output_details()

    # Build dummy inputs
    def dummy_input(detail):
        return np.random.rand(*detail["shape"]).astype(detail["dtype"])

    # Warmup
    for _ in range(3):
        for d in in_dets:
            interp.set_tensor(d["index"], dummy_input(d))
        interp.invoke()

    # Benchmark
    lats = []
    for _ in range(n_runs):
        t0 = time.perf_counter()
        for d in in_dets:
            interp.set_tensor(d["index"], dummy_input(d))
        interp.invoke()
        lats.append((time.perf_counter() - t0) * 1000)

    out = interp.get_tensor(out_dets[0]["index"])
    return {
        "size_mb"   : round(os.path.getsize(tflite_path) / 1024**2, 2),
        "avg_ms"    : round(float(np.mean(lats)), 2),
        "p95_ms"    : round(float(np.percentile(lats, 95)), 2),
        "inputs"    : [d["shape"].tolist() for d in in_dets],
        "out_sum"   : round(float(out[0].sum()), 4),
    }

print("\nBenchmark (50 runs, random input):\n")
bench_rows = []
for label, path in tflite_paths.items():
    try:
        s = bench_tflite(path)
        s["model"] = label
        bench_rows.append(s)
        print(f"{label}:")
        print(f"  Size     : {s['size_mb']} MB")
        print(f"  Avg      : {s['avg_ms']} ms")
        print(f"  P95      : {s['p95_ms']} ms")
        print(f"  Inputs   : {s['inputs']}")
        print(f"  Out sum  : {s['out_sum']} (should be ≈ 1.0)")
        print()
    except Exception as e:
        print(f"{label} benchmark error: {e}\n")

if bench_rows:
    bench_df = pd.DataFrame(bench_rows).set_index("model")
    print("── Summary ──")
    display(bench_df[["size_mb", "avg_ms", "p95_ms"]])
    bench_df.to_csv(os.path.join(RESULTS_DIR, "tflite_benchmark.csv"))
# Out:
# Benchmark (50 runs, random input):
#
# Visual benchmark error: name 'time' is not defined
